# %% [markdown]
# ### Validate & explore the database generated by our crawler
# the db will include more and more tables containing other things as we progress

# %%
import sqlite3
import os

# Connect to the database
conn = sqlite3.connect('../roster_reviews.sqlite.db')
cur = conn.cursor()

# %%
tables = cur.execute("SELECT name FROM sqlite_master WHERE type='table';").fetchall()
print("Tables in the database:", tables)
# Out:
# Tables in the database: [('sqlite_sequence',), ('subjects',), ('courses',), ('course_descriptions',)]

# %%
# go into the courses table and check if there are FA14 courses
cur.execute('SELECT * FROM courses WHERE semester="FA14" AND type="Lecture"').fetchall()
# Out:
# [(1,
#   'FA14',
#   'AAS',
#   'AAS 2130',
#   'Lecture',
#   '9638',
#   'Uris Hall 262',
#   'Tues & Thurs',
#   '11:40am - 12:55pm',
#   '',
#   'Chrissy Lau (cyl58)'),
#  (2,
#   'FA14',
#   'AAS',
#   'AAS 3030',
#   'Lecture',
#   '16453',
#   'Stimson Hall 119',
#   'Tues & Thurs',
#   '1:25pm - 2:40pm',
#   '',
#   'Viranjini Munasinghe (vpm1)'),
#  (3,
#   'FA14',
#   'AAS',
#   'AAS 3470',
#   'Lecture',
#   '17797',
#   'Rockefeller Hall 189',
#   'Mon & Wed',
#   '2:55pm - 4:10pm',
#   '',
#   'Chrissy Lau (cyl58)'),
#  (6,
#   'FA14',
#   'AEM',
#   'AEM 1230',
#   'Lecture',
#   '3794',
#   'Warren Hall B25',
#   'Mon & Wed',
#   '2:30pm - 3:20pm',
#   '',
#   'Pedro Perez (pdp5)'),
#  (7,
#   'FA14',
#   'AEM',
#   'AEM 1500',
#   'Lecture',
#   '17118',
#   'Warren Hall B25',
#   'Mon & Wed',
#   '10:10am - 11:00am',
#   '',
#   'Gregory Poe (glp2)'),
#  (11,
#   'FA14',
#   'AEM',
#   'AEM 2000',
#   'Lecture',
#   '16018',
#   'Warren Hall B02',
#   'Mon & Wed',
#   '11:15am - 12:05pm',
#   '',
#   'Chris Barrett (cbb2)'),
#  (18,
#   'FA14',
#   'AEM',
#   'AEM 2100',
#   'Lecture',
#   '4693',
#   'Warren Hall B25',
#   'Mon, Wed & Fri',
#   '1:25pm - 2:15pm',
#   '',
#   'Cindy Van Es (clv1)'),
#  (31,
#   'FA14',
#   'AEM',
#   'AEM 2200',
#   'Lecture',
#   '4471',
#   'Warren Hall B25',
#   'Mon, Wed & Fri',
#   '12:20pm - 1:10pm',
#   '',
#   'Pedro Perez (pdp5)'),
#  (33,
#   'FA14',
#   'AEM',
#   'AEM 2200',
#   'Lecture',
#   '17348',
#   'Stocking Hall 146',
#   'Mon, Wed & Fri',
#   '10:10am - 11:00am',
#   '',
#   'Aija Leiponen (ael24)'),
#  (34,
#   'FA14',
#   'AEM',
#   'AEM 2210',
#   'Lecture',
#   '1026',
#   'Morrison Hall 146',
#   'Tues & Thurs',
#   '10:10am - 11:25am',
#   '',
#   'Laurel Parrilli (lp393)'),
#  (35,
#   'FA14',
#   'AEM',
#   'AEM 2225',
#   'Lecture',
#   '16276',
#   'Plant Science Building 233',
#   'Mon, Wed & Fri',
#   '11:15am - 12:05pm',
#   '',
#   'John Little (jel52)'),
#  (44,
#   'FA14',
#   'AEM',
#   'AEM 2240',
#   'Lecture',
#   '1048',
#   'Kennedy Hall 116-Call Aud',
#   'Tues & Thurs',
#   '2:55pm - 4:10pm',
#   '',
#   'Rich Curtis (rtc3)'),
#  (47,
#   'FA14',
#   'AEM',
#   'AEM 2400',
#   'Lecture',
#   '1042',
#   'Kennedy Hall 116-Call Aud',
#   'Mon, Wed & Fri',
#   '10:10am - 11:00am',
#   '',
#   'Debra Perosio (djp7)'),
#  (48,
#   'FA14',
#   'AEM',
#   'AEM 2600',
#   'Lecture',
#   '4437',
#   'Warren Hall B25',
#   'Tues & Thurs',
#   '1:25pm - 2:40pm',
#   '',
#   'Garrick Blalock (gb78)'),
#  (49,
#   'FA14',
#   'AEM',
#   'AEM 2700',
#   'Lecture',
#   '15845',
#   'Warren Hall 101',
#   'Tues & Thurs',
#   '8:40am - 9:55am',
#   '',
#   'Brian Earle (boe1)'),
#  (50,
#   'FA14',
#   'AEM',
#   'AEM 2700',
#   'Lecture',
#   '15846',
#   'Warren Hall 101',
#   'Tues & Thurs',
#   '10:10am - 11:25am',
#   '',
#   'Brian Earle (boe1)'),
#  (51,
#   'FA14',
#   'AEM',
#   'AEM 2700',
#   'Lecture',
#   '15847',
#   'Warren Hall 101',
#   'Tues & Thurs',
#   '11:40am - 12:55pm',
#   '',
#   'Brian Earle (boe1)'),
#  (52,
#   'FA14',
#   'AEM',
#   'AEM 3020',
#   'Lecture',
#   '1044',
#   'M Van Rensselaer Hall G71',
#   'Mon, Wed & Fri',
#   '9:05am - 9:55am',
#   '',
#   'Wayne Knoblauch (wak4)'),
#  (55,
#   'FA14',
#   'AEM',
#   'AEM 3200',
#   'Lecture',
#   '1047',
#   'Warren Hall B25',
#   'Mon & Wed',
#   '8:40am - 9:55am',
#   '',
#   'Dale Grossman (dag14)'),
#  (56,
#   'FA14',
#   'AEM',
#   'AEM 3220',
#   'Lecture',
#   '4435',
#   'Warren Hall B02',
#   'Tues & Thurs',
#   '10:10am - 11:25am',
#   '',
#   'Aija Leiponen (ael24)'),
#  (57,
#   'FA14',
#   'AEM',
#   'AEM 3249',
#   'Lecture',
#   '4992',
#   'Malott Hall 253',
#   'Tues & Thurs',
#   '3:35pm - 4:25pm',
#   '',
#   'Deborah Streeter (dhs4)'),
#  (59,
#   'FA14',
#   'AEM',
#   'AEM 3270',
#   'Lecture',
#   '15332',
#   'Warren Hall B02',
#   'Tues & Thurs',
#   '11:40am - 12:55pm',
#   'Aug 26 - Oct 10, 2014',
#   'Bill Drake (wed5)'),
#  (60,
#   'FA14',
#   'AEM',
#   'AEM 3280',
#   'Lecture',
#   '4958',
#   'Statler Hall 351',
#   'Mon & Wed',
#   '10:10am - 11:25am',
#   '',
#   'Cathy Enz (cae4)'),
#  (61,
#   'FA14',
#   'AEM',
#   'AEM 3320',
#   'Lecture',
#   '4994',
#   'Malott Hall 253',
#   'Mon & Wed',
#   '2:55pm - 4:10pm',
#   '',
#   'Kevin Kniffin (kmk276)'),
#  (63,
#   'FA14',
#   'AEM',
#   'AEM 3360',
#   'Lecture',
#   '1327',
#   'Malott Hall 253',
#   'Tues & Thurs',
#   '10:10am - 11:25am',
#   '',
#   'Eric Yeung (pey4)'),
#  (64,
#   'FA14',
#   'AEM',
#   'AEM 3360',
#   'Lecture',
#   '4195',
#   'Malott Hall 253',
#   'Tues & Thurs',
#   '8:40am - 9:55am',
#   '',
#   'Eric Yeung (pey4)'),
#  (65,
#   'FA14',
#   'AEM',
#   'AEM 3380',
#   'Lecture',
#   '3803',
#   'Anabel Taylor Hall 114',
#   'Tues & Thurs',
#   '1:25pm - 2:40pm',
#   '',
#   'Anke Wessels (akw7)'),
#  (66,
#   'FA14',
#   'AEM',
#   'AEM 3440',
#   'Lecture',
#   '3759',
#   'Riley-Robb Hall 125',
#   'Mon & Wed',
#   '8:40am - 9:55am',
#   '',
#   'Brian Wansink (bcw28)'),
#  (67,
#   'FA14',
#   'AEM',
#   'AEM 3500',
#   'Lecture',
#   '5036',
#   'Bill and Melinda Gates Hll G01',
#   'Mon & Wed',
#   '10:10am - 11:25am',
#   '',
#   'Edith Liu (exl4)'),
#  (68,
#   'FA14',
#   'AEM',
#   'AEM 4010',
#   'Lecture',
#   '15287',
#   'Warren Hall 101',
#   'Wed',
#   '7:30pm - 9:25pm',
#   'Aug 26 - Oct 10, 2014',
#   'James Byrnes (jjb269)'),
#  (69,
#   'FA14',
#   'AEM',
#   'AEM 4020',
#   'Lecture',
#   '2643',
#   'Warren Hall 110',
#   'Wed',
#   '4:30pm - 7:00pm',
#   '',
#   'Brian Wansink (bcw28)'),
#  (70,
#   'FA14',
#   'AEM',
#   'AEM 4110',
#   'Lecture',
#   '17010',
#   'Warren Hall B02',
#   'Tues & Thurs',
#   '1:25pm - 2:40pm',
#   '',
#   'Loren Tauer (lwt1)'),
#  (72,
#   'FA14',
#   'AEM',
#   'AEM 4120',
#   'Lecture',
#   '4705',
#   'Warren Hall 101',
#   'Tues & Thurs',
#   '1:25pm - 2:40pm',
#   '',
#   'Carla Gomes (cpg5)'),
#  (73,
#   'FA14',
#   'AEM',
#   'AEM 4140',
#   'Lecture',
#   '1057',
#   'Malott Hall 251',
#   'Tues',
#   '10:10am - 11:25am',
#   '',
#   'William Schulze (wds3)'),
#  (78,
#   'FA14',
#   'AEM',
#   'AEM 4150',
#   'Lecture',
#   '1058',
#   'Warren Hall B25',
#   'Tues & Thurs',
#   '11:40am - 12:55pm',
#   '',
#   'Harry Kaiser (hmk2)'),
#  (79,
#   'FA14',
#   'AEM',
#   'AEM 4230',
#   'Lecture',
#   '15875',
#   'Malott Hall 251',
#   'Tues & Thurs',
#   '1:25pm - 2:40pm',
#   '',
#   'Vicki Bogan (vlb23)'),
#  (80,
#   'FA14',
#   'AEM',
#   'AEM 4260',
#   'Lecture',
#   '15942',
#   'Plant Science Building 135B',
#   'Tues & Thurs',
#   '10:10am - 11:25am',
#   '',
#   'Vicki Bogan (vlb23)'),
#  (82,
#   'FA14',
#   'AEM',
#   'AEM 4280',
#   'Lecture',
#   '4402',
#   'Warren Hall 101',
#   'Mon & Wed',
#   '8:40am - 9:55am',
#   '',
#   'David Ng (dtn4)'),
#  (84,
#   'FA14',
#   'AEM',
#   'AEM 4290',
#   'Lecture',
#   '4404',
#   'Warren Hall 101',
#   'Mon, Wed & Fri',
#   '10:10am - 11:00am',
#   '',
#   'David Ng (dtn4)'),
#  (86,
#   'FA14',
#   'AEM',
#   'AEM 4330',
#   'Lecture',
#   '5019',
#   'Sibley Hall 115',
#   'Wed & Fri',
#   '10:10am - 11:50am',
#   '',
#   'Mildred Warner (mew15)'),
#  (87,
#   'FA14',
#   'AEM',
#   'AEM 4400',
#   'Lecture',
#   '4440',
#   'Warren Hall 101',
#   'Mon & Wed',
#   '2:55pm - 4:10pm',
#   '',
#   'Ed McLaughlin (ewm3)'),
#  (88,
#   'FA14',
#   'AEM',
#   'AEM 4420',
#   'Lecture',
#   '1059',
#   'Bradfield Hall 101',
#   'Wed',
#   '7:30pm - 9:25pm',
#   '',
#   'Ralph Christy (rdc6)'),
#  (92,
#   'FA14',
#   'AEM',
#   'AEM 4450',
#   'Lecture',
#   '5022',
#   'Savage Hall 200',
#   'Thurs',
#   '10:10am - 11:25am',
#   '',
#   'Prabhu Pingali (plp39)'),
#  (95,
#   'FA14',
#   'AEM',
#   'AEM 4500',
#   'Lecture',
#   '1060',
#   'Warren Hall B02',
#   'Tues & Thurs',
#   '2:55pm - 4:10pm',
#   '',
#   'Jon Conrad (jmc16)'),
#  (96,
#   'FA14',
#   'AEM',
#   'AEM 4520',
#   'Lecture',
#   '4704',
#   'Morrison Hall 334',
#   'Tues & Thurs',
#   '8:40am - 9:55am',
#   '',
#   'Laurel Parrilli (lp393)'),
#  (97,
#   'FA14',
#   'AEM',
#   'AEM 4530',
#   'Lecture',
#   '1558',
#   'Plant Science Building G37',
#   'Tues & Thurs',
#   '10:10am - 11:25am',
#   '',
#   'John McKinley (jwm336)'),
#  (98,
#   'FA14',
#   'AEM',
#   'AEM 4545',
#   'Lecture',
#   '4996',
#   'Plant Science Building G37',
#   'Tues',
#   '2:00pm - 4:25pm',
#   '',
#   'Eswar Prasad (esp54)'),
#  (99,
#   'FA14',
#   'AEM',
#   'AEM 4560',
#   'Lecture',
#   '17109',
#   'Warren Hall 101',
#   'Tues & Thurs',
#   '2:55pm - 4:10pm',
#   '',
#   'John McKinley (jwm336)'),
#  (100,
#   'FA14',
#   'AEM',
#   'AEM 4570',
#   'Lecture',
#   '5037',
#   'Warren Hall B02',
#   'Mon',
#   '1:25pm - 4:25pm',
#   '',
#   'Edith Liu (exl4)'),
#  (101,
#   'FA14',
#   'AEM',
#   'AEM 4620',
#   'Lecture',
#   '15876',
#   'Mann Library B30B',
#   'Mon',
#   '10:10am - 11:25am',
#   '',
#   'Vicki Bogan (vlb23)'),
#  (103,
#   'FA14',
#   'AEM',
#   'AEM 4640',
#   'Lecture',
#   '4907',
#   'Warren Hall B02',
#   'Mon & Wed',
#   '12:20pm - 1:10pm',
#   '',
#   'Steven Kyle (sck5)'),
#  (104,
#   'FA14',
#   'AEM',
#   'AEM 4660',
#   'Lecture',
#   '15331',
#   'Phillips Hall 101',
#   'Wed',
#   '7:30pm - 10:00pm',
#   'Aug 26 - Oct 10, 2014',
#   'Deborah Streeter (dhs4)'),
#  (105,
#   'FA14',
#   'AEM',
#   'AEM 4940',
#   'Lecture',
#   '4748',
#   'Warren Hall 101',
#   'Fri',
#   '2:30pm - 4:25pm',
#   'Oct 13 - Dec 5, 2014',
#   'Cindy Van Es (clv1)'),
#  (111,
#   'FA14',
#   'AEM',
#   'AEM 6080',
#   'Lecture',
#   '1281',
#   'Warren Hall 113',
#   'Mon & Wed',
#   '10:10am - 11:25am',
#   '',
#   'Loren Tauer (lwt1)'),
#  (112,
#   'FA14',
#   'AEM',
#   'AEM 6325',
#   'Lecture',
#   '16023',
#   'Malott Hall 253',
#   'Mon & Wed',
#   '2:55pm - 4:10pm',
#   '',
#   'Kevin Kniffin (kmk276)'),
#  (113,
#   'FA14',
#   'AEM',
#   'AEM 6400',
#   'Lecture',
#   '4483',
#   'Warren Hall 137',
#   'Tues & Thurs',
#   '2:55pm - 4:10pm',
#   '',
#   'Harry Kaiser (hmk2)'),
#  (114,
#   'FA14',
#   'AEM',
#   'AEM 6440',
#   'Lecture',
#   '4995',
#   'Riley-Robb Hall 125',
#   'Mon & Wed',
#   '8:40am - 9:55am',
#   '',
#   'Brian Wansink (bcw28)'),
#  (115,
#   'FA14',
#   'AEM',
#   'AEM 6940',
#   'Lecture',
#   '4190',
#   'Warren Hall 137',
#   'Mon & Wed',
#   '8:00am - 9:55am',
#   '',
#   'David Just (drj3)'),
#  (172,
#   'FA14',
#   'AEM',
#   'AEM 7010',
#   'Lecture',
#   '1559',
#   'Warren Hall 113',
#   'Mon & Wed',
#   '12:20pm - 2:15pm',
#   '',
#   'Jura Liaukonyte (jl2545)'),
#  (175,
#   'FA14',
#   'AEM',
#   'AEM 7440',
#   'Lecture',
#   '3758',
#   'NONE',
#   'Mon & Wed',
#   '1:30pm - 4:00pm',
#   '',
#   'Brian Wansink (bcw28)'),
#  (176,
#   'FA14',
#   'AEM',
#   'AEM 7500',
#   'Lecture',
#   '4913',
#   'Warren Hall 138',
#   'Tues & Thurs',
#   '8:40am - 9:55am',
#   '',
#   'Jon Conrad (jmc16)'),
#  (177,
#   'FA14',
#   'AEM',
#   'AEM 7510',
#   'Lecture',
#   '17270',
#   'Warren Hall 138',
#   'Mon',
#   '2:00pm - 4:25pm',
#   '',
#   'Antonio Bento (amb396)'),
#  (179,
#   'FA14',
#   'AEM',
#   'AEM 7670',
#   'Lecture',
#   '1499',
#   'Warren Hall 113',
#   'Mon',
#   '5:00pm - 7:25pm',
#   '',
#   'Eswar Prasad (esp54)'),
#  (305,
#   'FA14',
#   'AEP',
#   'AEP 1100',
#   'Lecture',
#   '12531',
#   'Baker Laboratory 135',
#   'Tues & Thurs',
#   '10:10am - 11:00am',
#   '',
#   'Chris Xu (cx10)'),
#  (310,
#   'FA14',
#   'AEP',
#   'AEP 1200',
#   'Lecture',
#   '12310',
#   'Physical Sciences Building 120',
#   'Tues & Thurs',
#   '10:10am - 11:00am',
#   '',
#   'Frank Wise (fww1)'),
#  (315,
#   'FA14',
#   'AEP',
#   'AEP 2170',
#   'Lecture',
#   '11323',
#   'Rockefeller Hall 231',
#   'Mon, Wed & Fri',
#   '10:10am - 11:00am',
#   '',
#   'Lawrence Gibbons (lkg5)'),
#  (320,
#   'FA14',
#   'AEP',
#   'AEP 2640',
#   'Lecture',
#   '12947',
#   'Clark Hall 247',
#   'Mon',
#   '2:30pm - 4:25pm',
#   '',
#   'Gregory Fuchs (gdf9)'),
#  (325,
#   'FA14',
#   'AEP',
#   'AEP 3300',
#   'Lecture',
#   '11328',
#   'Rockefeller Hall 110',
#   'Fri',
#   '3:35pm - 4:25pm',
#   '',
#   'Ivan Bazarov (ib38)'),
#  (327,
#   'FA14',
#   'AEP',
#   'AEP 3330',
#   'Lecture',
#   '11179',
#   'Rockefeller Hall 132',
#   'Mon, Wed & Fri',
#   '10:10am - 11:00am',
#   '',
#   'Lisa Wickham (lw45)'),
#  (329,
#   'FA14',
#   'AEP',
#   'AEP 3550',
#   'Lecture',
#   '15347',
#   'Physical Sciences Building 120',
#   'Mon, Wed & Fri',
#   '9:05am - 9:55am',
#   'Oct 13 - Dec 5, 2014',
#   'Lois Pollack (lp26)'),
#  (331,
#   'FA14',
#   'AEP',
#   'AEP 3610',
#   'Lecture',
#   '15282',
#   'Physical Sciences Building 120',
#   'Mon, Wed & Fri',
#   '9:05am - 9:55am',
#   'Aug 26 - Oct 10, 2014',
#   'Lois Pollack (lp26)'),
#  (333,
#   'FA14',
#   'AEP',
#   'AEP 3630',
#   'Lecture',
#   '11330',
#   'Rockefeller Hall 115',
#   'Tues & Thurs',
#   '10:10am - 11:25am',
#   '',
#   'Sol Gruner (smg26)'),
#  (336,
#   'FA14',
#   'AEP',
#   'AEP 4130',
#   'Lecture',
#   '12857',
#   'Thurston Hall 205',
#   'Mon, Wed & Fri',
#   '11:15am - 12:05pm',
#   '',
#   'David Hammer (dah5)'),
#  (337,
#   'FA14',
#   'AEP',
#   'AEP 4210',
#   'Lecture',
#   '11174',
#   'Physical Sciences Building 120',
#   'Mon, Tues, Wed & Thurs',
#   '12:20pm - 1:10pm',
#   '',
#   'Thomas Stiadle (tas16)'),
#  (338,
#   'FA14',
#   'AEP',
#   'AEP 4230',
#   'Lecture',
#   '11181',
#   'Physical Sciences Building 120',
#   'Mon, Wed & Fri',
#   '10:10am - 11:00am',
#   '',
#   'Bruce Kusse (brk2)'),
#  (340,
#   'FA14',
#   'AEP',
#   'AEP 4380',
#   'Lecture',
#   '12957',
#   'Clark Hall 247',
#   'Mon, Wed & Fri',
#   '11:15am - 12:05pm',
#   '',
#   'Earl Kirkland (ejk14)'),
#  (341,
#   'FA14',
#   'AEP',
#   'AEP 4500',
#   'Lecture',
#   '11333',
#   'Rockefeller Hall 103',
#   'Tues & Thurs',
#   '10:10am - 11:25am',
#   '',
#   'David Muller (dm24)'),
#  (343,
#   'FA14',
#   'AEP',
#   'AEP 4700',
#   'Lecture',
#   '12480',
#   'Physical Sciences Building 120',
#   'Mon & Wed',
#   '2:55pm - 4:10pm',
#   '',
#   'Manfred Lindau (ml95)'),
#  (346,
#   'FA14',
#   'AEP',
#   'AEP 5570',
#   'Lecture',
#   '12023',
#   'Rockefeller Hall 231',
#   'Mon, Wed & Fri',
#   '9:05am - 9:55am',
#   '',
#   'Richard Lovelace (rvl1)'),
#  (347,
#   'FA14',
#   'AEP',
#   'AEP 6060',
#   'Lecture',
#   '11893',
#   'Phillips Hall 407',
#   'Tues & Thurs',
#   '10:10am - 11:25am',
#   '',
#   'David Hysell (dlh37)'),
#  (349,
#   'FA14',
#   'AEP',
#   'AEP 6610',
#   'Lecture',
#   '12326',
#   'Rockefeller Hall 115',
#   'Mon, Wed & Fri',
#   '2:30pm - 3:20pm',
#   '',
#   'Lena Kourkoutis (lf56)'),
#  (350,
#   'FA14',
#   'AEP',
#   'AEP 6630',
#   'Lecture',
#   '12329',
#   'Weill Hall 226',
#   'Tues & Thurs',
#   '11:40am - 12:55pm',
#   '',
#   'Michael Shuler (mls50)'),
#  (368,
#   'FA14',
#   'AGSCI',
#   'AGSCI 1125',
#   'Lecture',
#   '4728',
#   'Emerson Hall 135',
#   'Mon',
#   '11:15am - 12:05pm',
#   '',
#   'Antonio DiTommaso (ad97)'),
#  (369,
#   'FA14',
#   'AGSCI',
#   'AGSCI 2940',
#   'Lecture',
#   '3789',
#   'NONE',
#   '',
#   'None',
#   '',
#   'Antonio DiTommaso (ad97)'),
#  (372,
#   'FA14',
#   'AIRS',
#   'AIRS 1101',
#   'Lecture',
#   '15219',
#   'Barton Hall 203',
#   'Thurs',
#   '12:20pm - 1:10pm',
#   '',
#   'David Schrader (dms526)'),
#  (374,
#   'FA14',
#   'AIRS',
#   'AIRS 2201',
#   'Lecture',
#   '15220',
#   'Barton Hall 203',
#   'Thurs',
#   '1:25pm - 2:15pm',
#   '',
#   'David Schrader (dms526)'),
#  (376,
#   'FA14',
#   'AIRS',
#   'AIRS 3301',
#   'Lecture',
#   '16154',
#   'NONE',
#   'Tues & Thurs',
#   '1:10pm - 2:25pm',
#   '',
#   "Kevin O'Brien (kwo6)"),
#  (385,
#   'FA14',
#   'AIS',
#   'AIS 1100',
#   'Lecture',
#   '1022',
#   'Caldwell Hall 100',
#   'Tues & Thurs',
#   '1:25pm - 2:40pm',
#   '',
#   'Paul Nadasdy (pn79)'),
#  (389,
#   'FA14',
#   'AIS',
#   'AIS 3330',
#   'Lecture',
#   '4641',
#   'Fernow Hall G24',
#   'Tues & Thurs',
#   '8:40am - 9:55am',
#   '',
#   'Karim-Aly Kassam (ksk28)'),
#  (393,
#   'FA14',
#   'ALS',
#   'ALS 3210',
#   'Lecture',
#   '18315',
#   'Caldwell Hall 282',
#   'Wed',
#   '7:30pm - 9:55pm',
#   'Sep 3 - Oct 8, 2014',
#   'Richard Kiely (rck6)'),
#  (394,
#   'FA14',
#   'ALS',
#   'ALS 4000',
#   'Lecture',
#   '17110',
#   'Stimson Hall 105',
#   'Tues',
#   '2:30pm - 4:25pm',
#   '',
#   'Susan Riley (sfr4)'),
#  (395,
#   'FA14',
#   'ALS',
#   'ALS 4940',
#   'Lecture',
#   '17676',
#   'Warren Hall 101',
#   'Mon & Wed',
#   '12:20pm - 1:10pm',
#   'Aug 26 - Oct 10, 2014',
#   'Jennifer DeRosa (jd242)'),
#  (396,
#   'FA14',
#   'ALS',
#   'ALS 4940',
#   'Lecture',
#   '15406',
#   'NONE',
#   'Mon',
#   '5:00pm - 8:00pm',
#   'Oct 20 - Nov 17, 2014',
#   'Marcia Eames-Sheavly (me14)'),
#  (397,
#   'FA14',
#   'ALS',
#   'ALS 4940',
#   'Lecture',
#   '15407',
#   'NONE',
#   'Wed',
#   '5:00pm - 8:00pm',
#   'Oct 22 - Nov 19, 2014',
#   'Marcia Eames-Sheavly (me14)'),
#  (398,
#   'FA14',
#   'ALS',
#   'ALS 4940',
#   'Lecture',
#   '16900',
#   'NONE',
#   'Tues',
#   '5:00pm - 8:00pm',
#   'Oct 21 - Nov 18, 2014',
#   'Marcia Eames-Sheavly (me14)'),
#  (404,
#   'FA14',
#   'ALS',
#   'ALS 5780',
#   'Lecture',
#   '4140',
#   'Computing & Communications 421',
#   'Tues & Thurs',
#   '10:10am - 11:25am',
#   '',
#   'Kimberly Kenyon (kpk9)'),
#  (405,
#   'FA14',
#   'ALS',
#   'ALS 5780',
#   'Lecture',
#   '4141',
#   'Computing & Communications 421',
#   'Mon & Wed',
#   '4:35pm - 5:50pm',
#   '',
#   'Kimberly Kenyon (kpk9)'),
#  (406,
#   'FA14',
#   'ALS',
#   'ALS 5780',
#   'Lecture',
#   '4142',
#   'Computing & Communications 421',
#   'Tues & Thurs',
#   '8:40am - 9:55am',
#   '',
#   'Kimberly Kenyon (kpk9)'),
#  (419,
#   'FA14',
#   'ALS',
#   'ALS 6015',
#   'Lecture',
#   '4194',
#   'Kennedy Hall 105',
#   'Wed',
#   '2:30pm - 4:25pm',
#   '',
#   'David Way (dgw2)'),
#  (420,
#   'FA14',
#   'ALS',
#   'ALS 6015',
#   'Lecture',
#   '4752',
#   'Kennedy Hall 105',
#   'Thurs',
#   '4:00pm - 6:00pm',
#   '',
#   'David Way (dgw2)'),
#  (422,
#   'FA14',
#   'AMST',
#   'AMST 1500',
#   'Lecture',
#   '16809',
#   'NONE',
#   'Mon & Wed',
#   '2:55pm - 4:10pm',
#   '',
#   'Riche Richardson (rdr83)'),
#  (423,
#   'FA14',
#   'AMST',
#   'AMST 1581',
#   'Lecture',
#   '15702',
#   'Mcgraw Hall 165',
#   'Tues & Thurs',
#   '9:05am - 9:55am',
#   '',
#   'Jon Parmenter (jwp35)'),
#  (428,
#   'FA14',
#   'AMST',
#   'AMST 1600',
#   'Lecture',
#   '7649',
#   'Caldwell Hall 100',
#   'Tues & Thurs',
#   '1:25pm - 2:40pm',
#   '',
#   'Paul Nadasdy (pn79)'),
#  (432,
#   'FA14',
#   'AMST',
#   'AMST 2003',
#   'Lecture',
#   '16720',
#   'Goldwin Smith Hall 132-HEC Aud',
#   'Tues & Thurs',
#   '2:55pm - 4:10pm',
#   '',
#   'Glenn Altschuler (gca1)'),
#  (433,
#   'FA14',
#   'AMST',
#   'AMST 2006',
#   'Lecture',
#   '16938',
#   'Lincoln Hall B20',
#   'Tues & Thurs',
#   '3:35pm - 4:25pm',
#   '',
#   'Tom McEnaney (tpm88)'),
#  (438,
#   'FA14',
#   'AMST',
#   'AMST 2331',
#   'Lecture',
#   '8453',
#   'Rockefeller Hall 231',
#   'Mon, Wed & Fri',
#   '12:20pm - 1:10pm',
#   '',
#   'Margaret Rossiter (mwr4)'),
#  (439,
#   'FA14',
#   'AMST',
#   'AMST 2640',
#   'Lecture',
#   '9639',
#   'Uris Hall 262',
#   'Tues & Thurs',
#   '11:40am - 12:55pm',
#   '',
#   'Chrissy Lau (cyl58)'),
#  (441,
#   'FA14',
#   'AMST',
#   'AMST 2675',
#   'Lecture',
#   '16877',
#   'Rockefeller Hall 104',
#   'Mon, Wed & Fri',
#   '10:10am - 11:00am',
#   '',
#   'Jeremy Braddock (jb358)'),
#  (442,
#   'FA14',
#   'AMST',
#   'AMST 2710',
#   'Lecture',
#   '6750',
#   'Bradfield Hall 101',
#   'Tues & Thurs',
#   '1:25pm - 2:40pm',
#   '',
#   'John Sipple (jws28)'),
#  (450,
#   'FA14',
#   'AMST',
#   'AMST 3140',
#   'Lecture',
#   '17405',
#   'Rockefeller Hall 230',
#   'Mon & Wed',
#   '12:20pm - 1:10pm',
#   '',
#   'Molly Geidel (mjg365)'),
#  (454,
#   'FA14',
#   'AMST',
#   'AMST 3230',
#   'Lecture',
#   '16414',
#   'Goldwin Smith Hall G76-Lewis',
#   'Tues & Thurs',
#   '8:40am - 9:55am',
#   '',
#   'Thomas Lyons (tpl4)'),
#  (455,
#   'FA14',
#   'AMST',
#   'AMST 3281',
#   'Lecture',
#   '17190',
#   'Myron Taylor Hall G90',
#   'Mon & Wed',
#   '2:55pm - 4:10pm',
#   '',
#   'Dawn Chutkow (dmc66)'),
#  (456,
#   'FA14',
#   'AMST',
#   'AMST 3330',
#   'Lecture',
#   '8418',
#   'Fernow Hall G24',
#   'Tues & Thurs',
#   '8:40am - 9:55am',
#   '',
#   'Karim-Aly Kassam (ksk28)'),
#  (458,
#   'FA14',
#   'AMST',
#   'AMST 3450',
#   'Lecture',
#   '15733',
#   'White Hall 106',
#   'Mon & Wed',
#   '9:05am - 9:55am',
#   '',
#   'Aaron Sachs (as475)'),
#  (461,
#   'FA14',
#   'AMST',
#   'AMST 3470',
#   'Lecture',
#   '17799',
#   'Rockefeller Hall 189',
#   'Mon & Wed',
#   '2:55pm - 4:10pm',
#   '',
#   'Chrissy Lau (cyl58)'),
#  (462,
#   'FA14',
#   'AMST',
#   'AMST 3515',
#   'Lecture',
#   '16348',
#   'Goldwin Smith Hall G22',
#   'Tues & Thurs',
#   '1:25pm - 2:40pm',
#   '',
#   'Cheryl Finley (cf86)'),
#  (464,
#   'FA14',
#   'AMST',
#   'AMST 3605',
#   'Lecture',
#   '8428',
#   'Goldwin Smith Hall G64-Kau Aud',
#   'Tues & Thurs',
#   '11:40am - 12:55pm',
#   '',
#   'Judith Bernstock (jeb24)'),
#  (465,
#   'FA14',
#   'AMST',
#   'AMST 3665',
#   'Lecture',
#   '8176',
#   'Bill and Melinda Gates Hll G01',
#   'Tues & Thurs',
#   '11:40am - 12:55pm',
#   '',
#   'Isaac Kramnick (ik15)'),
#  (472,
#   'FA14',
#   'AMST',
#   'AMST 3672',
#   'Lecture',
#   '16921',
#   'Goldwin Smith Hall G22',
#   'Tues & Thurs',
#   '10:10am - 11:25am',
#   '',
#   'Ananda Cohen Suarez (aic42)'),
#  (473,
#   'FA14',
#   'AMST',
#   'AMST 3703',
#   'Lecture',
#   '17786',
#   'Stimson Hall 119',
#   'Tues & Thurs',
#   '1:25pm - 2:40pm',
#   '',
#   'Viranjini Munasinghe (vpm1)'),
#  (474,
#   'FA14',
#   'AMST',
#   'AMST 3777',
#   'Lecture',
#   '16099',
#   'White Hall 110',
#   'Tues & Thurs',
#   '2:55pm - 4:10pm',
#   '',
#   'Vilma Santiago-Irizarry (vs23)'),
#  (475,
#   'FA14',
#   'AMST',
#   'AMST 3830',
#   'Lecture',
#   '15754',
#   'Goldwin Smith Hall G22',
#   'Tues & Thurs',
#   '2:55pm - 4:10pm',
#   '',
#   'Maria Cristina Garcia (mcg20)'),
#  (485,
#   'FA14',
#   'AMST',
#   'AMST 4655',
#   'Lecture',
#   '8651',
#   'Uris Hall G26',
#   'Thurs',
#   '2:30pm - 4:25pm',
#   '',
#   'Richard Miller (rwm5)'),
#  (492,
#   'FA14',
#   'AMST',
#   'AMST 5710',
#   'Lecture',
#   '6756',
#   'Bradfield Hall 101',
#   'Tues & Thurs',
#   '1:25pm - 2:40pm',
#   '',
#   'John Sipple (jws28)'),
#  (504,
#   'FA14',
#   'AMST',
#   'AMST 6656',
#   'Lecture',
#   '8654',
#   'Uris Hall G26',
#   'Thurs',
#   '2:30pm - 4:25pm',
#   '',
#   'Richard Miller (rwm5)'),
#  (506,
#   'FA14',
#   'ANSC',
#   'ANSC 1100',
#   'Lecture',
#   '4053',
#   'Morrison Hall 146',
#   'Mon, Wed & Fri',
#   '9:05am - 9:55am',
#   '',
#   'James Giles (jrg9)'),
#  (509,
#   'FA14',
#   'ANSC',
#   'ANSC 2120',
#   'Lecture',
#   '1064',
#   'Morrison Hall 146',
#   'Mon, Wed & Fri',
#   '10:10am - 11:00am',
#   '',
#   'Debbie Cherney (djc6)'),
#  (514,
#   'FA14',
#   'ANSC',
#   'ANSC 2150',
#   'Lecture',
#   '1070',
#   'Morrison Hall 146',
#   'Mon',
#   '2:30pm - 4:25pm',
#   '',
#   'Donna Muscarella (dem10)'),
#  (515,
#   'FA14',
#   'ANSC',
#   'ANSC 2500',
#   'Lecture',
#   '1073',
#   'Morrison Hall 164',
#   'Tues & Thurs',
#   '10:10am - 11:00am',
#   '',
#   'Mike Van Amburgh (mev1)'),
#  (517,
#   'FA14',
#   'ANSC',
#   'ANSC 2650',
#   'Lecture',
#   '1331',
#   'Morrison Hall 146',
#   'Tues & Thurs',
#   '9:05am - 9:55am',
#   '',
#   'Eva Conant (ecc26)'),
#  (519,
#   'FA14',
#   'ANSC',
#   'ANSC 3100',
#   'Lecture',
#   '1333',
#   'Morrison Hall 146',
#   'Wed',
#   '12:20pm - 2:15pm',
#   '',
#   'Debbie Cherney (djc6)'),
#  (520,
#   'FA14',
#   'ANSC',
#   'ANSC 3400',
#   'Lecture',
#   '16275',
#   'Morrison Hall 163',
#   'Tues & Thurs',
#   '11:15am - 12:05pm',
#   '',
#   'W. Butler (wrb2)'),
#  (521,
#   'FA14',
#   'ANSC',
#   'ANSC 3540',
#   'Lecture',
#   '1090',
#   'Morrison Hall 164',
#   'Tues & Thurs',
#   '9:05am - 9:55am',
#   '',
#   'Thomas Overton (tro2)'),
#  (523,
#   'FA14',
#   'ANSC',
#   'ANSC 4000',
#   'Lecture',
#   '4476',
#   'Morrison Hall 342',
#   'Mon & Wed',
#   '7:30pm - 8:45pm',
#   '',
#   'Dan Brown (dlb20)'),
#  (525,
#   'FA14',
#   'ANSC',
#   'ANSC 4110',
#   'Lecture',
#   '1093',
#   'Morrison Hall 164',
#   'Mon, Wed & Fri',
#   '10:10am - 11:00am',
#   '',
#   'Mike Van Amburgh (mev1)'),
#  (527,
#   'FA14',
#   'ANSC',
#   'ANSC 4270',
#   'Lecture',
#   '3754',
#   'Morrison Hall 164',
#   'Mon, Wed & Fri',
#   '9:05am - 9:55am',
#   '',
#   'Susan Quirk (smq1)'),
#  (528,
#   'FA14',
#   'ANSC',
#   'ANSC 4400',
#   'Lecture',
#   '15327',
#   'Morrison Hall 342',
#   'Wed',
#   '2:30pm - 4:25pm',
#   'Aug 26 - Oct 10, 2014',
#   'Rodney Dietert (rrd1)'),
#  (529,
#   'FA14',
#   'ANSC',
#   'ANSC 4510',
#   'Lecture',
#   '1098',
#   'Morrison Hall 164',
#   'Wed',
#   '1:25pm - 4:25pm',
#   '',
#   'Jason Karszes (jk57)'),
#  (539,
#   'FA14',
#   'ANSC',
#   'ANSC 6940',
#   'Lecture',
#   '4595',
#   'NONE',
#   '',
#   'None',
#   '',
#   'Quirine Ketterings (qmk2)'),
#  (540,
#   'FA14',
#   'ANSC',
#   'ANSC 6940',
#   'Lecture',
#   '18432',
#   'NONE',
#   '',
#   'None',
#   '',
#   'Mike Van Amburgh (mev1)'),
#  (624,
#   'FA14',
#   'ANTHR',
#   'ANTHR 1400',
#   'Lecture',
#   '6804',
#   'Goldwin Smith Hall 132-HEC Aud',
#   'Mon & Wed',
#   '12:20pm - 1:10pm',
#   '',
#   'David Holmberg (dhh8)'),
#  (633,
#   'FA14',
#   'ANTHR',
#   'ANTHR 1401',
#   'Lecture',
#   '6813',
#   'McGraw Hall 215',
#   'Wed',
#   '7:30pm - 8:30pm',
#   '',
#   'David Holmberg (dhh8)'),
#  (634,
#   'FA14',
#   'ANTHR',
#   'ANTHR 2015',
#   'Lecture',
#   '15832',
#   'Goldwin Smith Hall 142',
#   'Mon & Wed',
#   '2:55pm - 4:10pm',
#   '',
#   'Lori Khatchadourian (lk323)'),
#  (635,
#   'FA14',
#   'ANTHR',
#   'ANTHR 2310',
#   'Lecture',
#   '16450',
#   'Goldwin Smith Hall 132-HEC Aud',
#   'Mon, Wed & Fri',
#   '11:15am - 12:05pm',
#   '',
#   'Adam Arcadi (apc13)'),
#  (636,
#   'FA14',
#   'ANTHR',
#   'ANTHR 2421',
#   'Lecture',
#   '5795',
#   'Uris Hall 262',
#   'Mon & Wed',
#   '12:20pm - 1:10pm',
#   '',
#   'Kathryn March (ksm8)'),
#  (641,
#   'FA14',
#   'ANTHR',
#   'ANTHR 2468',
#   'Lecture',
#   '7026',
#   'Mcgraw Hall 165',
#   'Tues & Thurs',
#   '11:40am - 12:55pm',
#   '',
#   'Stacey Langwick (sal54)'),
#  (650,
#   'FA14',
#   'ANTHR',
#   'ANTHR 2472',
#   'Lecture',
#   '8222',
#   'McGraw Hall 366',
#   'Tues & Thurs',
#   '10:10am - 11:25am',
#   '',
#   'Davydd Greenwood (djg6)'),
#  (651,
#   'FA14',
#   'ANTHR',
#   'ANTHR 2595',
#   'Lecture',
#   '17666',
#   'Uris Hall 262',
#   'Tues & Thurs',
#   '2:55pm - 4:10pm',
#   '',
#   'Yohko Tsuji (yt33)'),
#  (652,
#   'FA14',
#   'ANTHR',
#   'ANTHR 2750',
#   'Lecture',
#   '9013',
#   'Savage Hall 100',
#   'Mon & Wed',
#   '10:10am - 11:00am',
#   '',
#   'Zhenglong Gu (zg27)'),
#  (659,
#   'FA14',
#   'ANTHR',
#   'ANTHR 3000',
#   'Lecture',
#   '8224',
#   'McGraw Hall 215',
#   'Tues & Thurs',
#   '11:40am - 12:55pm',
#   '',
#   'Vilma Santiago-Irizarry (vs23)'),
#  (661,
#   'FA14',
#   'ANTHR',
#   'ANTHR 3255',
#   'Lecture',
#   '16091',
#   'Morrill Hall 107',
#   'Tues & Thurs',
#   '1:25pm - 2:40pm',
#   '',
#   'John Henderson (jsh6)'),
#  (662,
#   'FA14',
#   'ANTHR',
#   'ANTHR 3462',
#   'Lecture',
#   '7993',
#   'McGraw Hall 215',
#   'Tues & Thurs',
#   '1:25pm - 2:40pm',
#   '',
#   'Davydd Greenwood (djg6)'),
#  (663,
#   'FA14',
#   'ANTHR',
#   'ANTHR 3516',
#   'Lecture',
#   '16320',
#   'Uris Hall 438',
#   'Tues & Thurs',
#   '10:10am - 11:25am',
#   '',
#   'Marina Welker (maw82)'),
#  (664,
#   'FA14',
#   'ANTHR',
#   'ANTHR 3545',
#   'Lecture',
#   '8568',
#   'McGraw Hall B65',
#   'Mon & Wed',
#   '2:55pm - 4:10pm',
#   '',
#   'Kathryn March (ksm8)'),
#  (665,
#   'FA14',
#   'ANTHR',
#   'ANTHR 3703',
#   'Lecture',
#   '16452',
#   'Stimson Hall 119',
#   'Tues & Thurs',
#   '1:25pm - 2:40pm',
#   '',
#   'Viranjini Munasinghe (vpm1)'),
#  (666,
#   'FA14',
#   'ANTHR',
#   'ANTHR 3777',
#   'Lecture',
#   '16097',
#   'White Hall 110',
#   'Tues & Thurs',
#   '2:55pm - 4:10pm',
#   '',
#   'Vilma Santiago-Irizarry (vs23)'),
#  (765,
#   'FA14',
#   'ANTHR',
#   'ANTHR 6462',
#   'Lecture',
#   '7994',
#   'McGraw Hall 215',
#   'Tues & Thurs',
#   '1:25pm - 2:40pm',
#   '',
#   'Davydd Greenwood (djg6)'),
#  (873,
#   'FA14',
#   'ARCH',
#   'ARCH 1611',
#   'Lecture',
#   '5467',
#   'Milstein Hall 101',
#   'Mon & Wed',
#   '9:05am - 11:00am',
#   '',
#   'David Turnbull (dmt87)'),
#  (874,
#   'FA14',
#   'ARCH',
#   'ARCH 1801',
#   'Lecture',
#   '5253',
#   'Balch Hall - Tatkon Ctr 3330',
#   'Tues & Thurs',
#   '12:20pm - 2:15pm',
#   '',
#   'Chad Randl (cgr5)'),
#  (877,
#   'FA14',
#   'ARCH',
#   'ARCH 2301',
#   'Lecture',
#   '5684',
#   'Milstein Hall 101',
#   'Thurs',
#   '2:30pm - 4:25pm',
#   '',
#   'Arthur Ovaska (aao4)'),
#  (878,
#   'FA14',
#   'ARCH',
#   'ARCH 2613',
#   'Lecture',
#   '5560',
#   'Milstein Hall 101',
#   'Tues & Thurs',
#   '9:05am - 11:00am',
#   '',
#   'Mark Cruvellier (mrc14)'),
#  (879,
#   'FA14',
#   'ARCH',
#   'ARCH 2614',
#   'Lecture',
#   '5562',
#   'Sibley Hall 157',
#   'Mon & Wed',
#   '9:45am - 11:00am',
#   '',
#   'Jonathan Ochshorn (jo24)'),
#  (886,
#   'FA14',
#   'ARCH',
#   'ARCH 3301',
#   'Lecture',
#   '15820',
#   'Rome, Italy',
#   '',
#   'None',
#   '',
#   'Val Warke (vkw1)'),
#  (895,
#   'FA14',
#   'ARCH',
#   'ARCH 3311',
#   'Lecture',
#   '16965',
#   'Sibley Hall 157',
#   'Fri',
#   '10:10am - 12:05pm',
#   '',
#   'Leonard Mirin (ljm3)'),
#  (897,
#   'FA14',
#   'ARCH',
#   'ARCH 3702',
#   'Lecture',
#   '5571',
#   'Milstein Hall 101',
#   'Tues & Thurs',
#   '11:15am - 12:05pm',
#   '',
#   'Donald Greenberg (dpg5)'),
#  (901,
#   'FA14',
#   'ARCH',
#   'ARCH 3821',
#   'Lecture',
#   '15819',
#   'Sibley Hall 157',
#   'Tues & Thurs',
#   '11:15am - 12:05pm',
#   '',
#   'Leonard Mirin (ljm3)'),
#  (902,
#   'FA14',
#   'ARCH',
#   'ARCH 3823',
#   'Lecture',
#   '16319',
#   'Rome, Italy',
#   '',
#   'None',
#   '',
#   'Jeffrey Blanchard (jnb10)'),
#  (915,
#   'FA14',
#   'ARCH',
#   'ARCH 4513',
#   'Lecture',
#   '5708',
#   'Rand Hall 205',
#   'Tues',
#   '2:30pm - 4:25pm',
#   '',
#   'George Hascup (geh8)'),
#  (916,
#   'FA14',
#   'ARCH',
#   'ARCH 4601',
#   'Lecture',
#   '16360',
#   'Malott Hall 203',
#   'Tues & Thurs',
#   '10:10am - 11:25am',
#   '',
#   'John Elliott (jre15)'),
#  (922,
#   'FA14',
#   'ARCH',
#   'ARCH 4613',
#   'Lecture',
#   '5709',
#   'Rand Hall 205',
#   'Tues',
#   '2:30pm - 4:25pm',
#   '',
#   'George Hascup (geh8)'),
#  (931,
#   'FA14',
#   'ARCH',
#   'ARCH 5201',
#   'Lecture',
#   '5682',
#   'AAP in NYC',
#   'Wed',
#   '6:00pm - 9:00pm',
#   '',
#   'James Greenberg (jbg68)'),
#  (934,
#   'FA14',
#   'ARCH',
#   'ARCH 5301',
#   'Lecture',
#   '5419',
#   'Sibley Hall 157',
#   'Tues',
#   '2:30pm - 4:25pm',
#   '',
#   'Lily Chi (lhc3)'),
#  (935,
#   'FA14',
#   'ARCH',
#   'ARCH 5511',
#   'Lecture',
#   '5271',
#   'Sibley Hall 157',
#   'Thurs',
#   '2:30pm - 4:25pm',
#   '',
#   'Tao DuFour (tns29)'),
#  (936,
#   'FA14',
#   'ARCH',
#   'ARCH 5611',
#   'Lecture',
#   '5468',
#   'Milstein Hall 101',
#   'Mon & Wed',
#   '9:05am - 11:00am',
#   '',
#   'David Turnbull (dmt87)'),
#  (937,
#   'FA14',
#   'ARCH',
#   'ARCH 5613',
#   'Lecture',
#   '5563',
#   'Milstein Hall 101',
#   'Tues & Thurs',
#   '9:05am - 11:00am',
#   '',
#   'Mark Cruvellier (mrc14)'),
#  (938,
#   'FA14',
#   'ARCH',
#   'ARCH 5614',
#   'Lecture',
#   '5564',
#   'Sibley Hall 157',
#   'Mon & Wed',
#   '9:45am - 11:00am',
#   '',
#   'Jonathan Ochshorn (jo24)'),
#  (939,
#   'FA14',
#   'ARCH',
#   'ARCH 5614',
#   'Lecture',
#   '17903',
#   'Hollister Hall 372',
#   'Tues & Thurs',
#   '10:10am - 11:25am',
#   '',
#   'Jonathan Ochshorn (jo24)'),
#  (940,
#   'FA14',
#   'ARCH',
#   'ARCH 5801',
#   'Lecture',
#   '5288',
#   'Balch Hall - Tatkon Ctr 3330',
#   'Tues & Thurs',
#   '12:20pm - 2:15pm',
#   '',
#   'Chad Randl (cgr5)'),
#  (950,
#   'FA14',
#   'ARCH',
#   'ARCH 6311',
#   'Lecture',
#   '16966',
#   'Sibley Hall 157',
#   'Fri',
#   '10:10am - 12:05pm',
#   '',
#   'Leonard Mirin (ljm3)'),
#  (957,
#   'FA14',
#   'ARCH',
#   'ARCH 6605',
#   'Lecture',
#   '18132',
#   'Rand Hall 202',
#   'Tues',
#   '2:30pm - 4:25pm',
#   '',
#   'Martin Miller (mfm97)'),
#  (958,
#   'FA14',
#   'ARCH',
#   'ARCH 6605',
#   'Lecture',
#   '18133',
#   'Rand Hall 205',
#   'Thurs',
#   '12:20pm - 2:15pm',
#   '',
#   'Suzanne Lettieri (stl27)'),
#  (959,
#   'FA14',
#   'ARCH',
#   'ARCH 6605',
#   'Lecture',
#   '18134',
#   'Rand Hall 205',
#   'Wed',
#   '10:10am - 12:05pm',
#   '',
#   'Aleksandr Mergold (am71)'),
#  (971,
#   'FA14',
#   'ARKEO',
#   'ARKEO 2015',
#   'Lecture',
#   '15833',
#   'Goldwin Smith Hall 142',
#   'Mon & Wed',
#   '2:55pm - 4:10pm',
#   '',
#   'Lori Khatchadourian (lk323)'),
#  (972,
#   'FA14',
#   'ARKEO',
#   'ARKEO 2610',
#   'Lecture',
#   '8037',
#   'Kennedy Hall 117',
#   'Fri',
#   '1:25pm - 4:25pm',
#   '',
#   'Sherene Baugher (sbb8)'),
#  (973,
#   'FA14',
#   'ARKEO',
#   'ARKEO 2641',
#   'Lecture',
#   '17975',
#   'Rockefeller Hall 231',
#   'Tues & Thurs',
#   '10:10am - 11:25am',
#   '',
#   'Courtney Roby (car295)'),
#  (996,
#   'FA14',
#   'ARKEO',
#   'ARKEO 3090',
#   'Lecture',
#   '6468',
#   'Goldwin Smith Hall B48',
#   'Wed',
#   '12:20pm - 1:10pm',
#   '',
#   'Sturt Manning (sm456)'),
#  (998,
#   'FA14',
#   'ARKEO',
#   'ARKEO 3255',
#   'Lecture',
#   '16092',
#   'Morrill Hall 107',
#   'Tues & Thurs',
#   '1:25pm - 2:40pm',
#   '',
#   'John Henderson (jsh6)'),
#  (999,
#   'FA14',
#   'ARKEO',
#   'ARKEO 3800',
#   'Lecture',
#   '8566',
#   'Goldwin Smith Hall G22',
#   'Tues & Thurs',
#   '11:40am - 12:55pm',
#   '',
#   'An-Yi Pan (ap76)'),
#  (1007,
#   'FA14',
#   'ARKEO',
#   'ARKEO 4755',
#   'Lecture',
#   '18191',
#   'Goldwin Smith Hall B48',
#   'Wed',
#   '12:20pm - 1:10pm',
#   '',
#   'Sturt Manning (sm456)'),
#  (1112,
#   'FA14',
#   'ART',
#   'ART 2907',
#   'Lecture',
#   '5570',
#   'Milstein Hall 101',
#   'Tues & Thurs',
#   '11:15am - 12:05pm',
#   '',
#   'Donald Greenberg (dpg5)'),
#  (1154,
#   'FA14',
#   'ARTH',
#   'ARTH 2400',
#   'Lecture',
#   '8010',
#   'Goldwin Smith Hall 132-HEC Aud',
#   'Tues & Thurs',
#   '10:10am - 11:25am',
#   '',
#   'Claudia Lazzaro (cl47)'),
#  (1160,
#   'FA14',
#   'ARTH',
#   'ARTH 3250',
#   'Lecture',
#   '6467',
#   'Goldwin Smith Hall B48',
#   'Wed',
#   '12:20pm - 1:10pm',
#   '',
#   'Sturt Manning (sm456)'),
#  (1162,
#   'FA14',
#   'ARTH',
#   'ARTH 3505',
#   'Lecture',
#   '16347',
#   'Goldwin Smith Hall G22',
#   'Tues & Thurs',
#   '1:25pm - 2:40pm',
#   '',
#   'Cheryl Finley (cf86)'),
#  (1163,
#   'FA14',
#   'ARTH',
#   'ARTH 3605',
#   'Lecture',
#   '8427',
#   'Goldwin Smith Hall G64-Kau Aud',
#   'Tues & Thurs',
#   '11:40am - 12:55pm',
#   '',
#   'Judith Bernstock (jeb24)'),
#  (1164,
#   'FA14',
#   'ARTH',
#   'ARTH 3650',
#   'Lecture',
#   '16322',
#   'Goldwin Smith Hall G22',
#   'Mon & Wed',
#   '2:55pm - 4:10pm',
#   '',
#   'Maria Fernandez (mf252)'),
#  (1165,
#   'FA14',
#   'ARTH',
#   'ARTH 3670',
#   'Lecture',
#   '16460',
#   'Goldwin Smith Hall G22',
#   'Tues & Thurs',
#   '10:10am - 11:25am',
#   '',
#   'Ananda Cohen Suarez (aic42)'),
#  (1166,
#   'FA14',
#   'ARTH',
#   'ARTH 3800',
#   'Lecture',
#   '8564',
#   'Goldwin Smith Hall G22',
#   'Tues & Thurs',
#   '11:40am - 12:55pm',
#   '',
#   'An-Yi Pan (ap76)'),
#  (1240,
#   'FA14',
#   'ASIAN',
#   'ASIAN 1191',
#   'Lecture',
#   '6477',
#   'Mcgraw Hall 165',
#   'Mon & Wed',
#   '10:10am - 11:00am',
#   '',
#   'Tamara Loos (tl14)'),
#  (1245,
#   'FA14',
#   'ASIAN',
#   'ASIAN 2211',
#   'Lecture',
#   '9146',
#   'Goldwin Smith Hall G64-Kau Aud',
#   'Mon & Wed',
#   '12:20pm - 1:10pm',
#   '',
#   'Janice Kanemitsu (jsk327)'),
#  (1250,
#   'FA14',
#   'ASIAN',
#   'ASIAN 2215',
#   'Lecture',
#   '8110',
#   'Baker Laboratory 119',
#   'Tues & Thurs',
#   '10:10am - 11:25am',
#   '',
#   'Anne Blackburn (amb242)'),
#  (1251,
#   'FA14',
#   'ASIAN',
#   'ASIAN 2245',
#   'Lecture',
#   '6486',
#   'Lincoln Hall B24',
#   'Mon & Fri',
#   '2:30pm - 3:20pm',
#   '',
#   'Christopher Miller (cjm299)'),
#  (1252,
#   'FA14',
#   'ASIAN',
#   'ASIAN 2247',
#   'Lecture',
#   '15672',
#   'Morrill Hall 106',
#   'Mon & Wed',
#   '2:55pm - 4:10pm',
#   '',
#   'Chiara Formichi (cf398)'),
#  (1253,
#   'FA14',
#   'ASIAN',
#   'ASIAN 2255',
#   'Lecture',
#   '15673',
#   'Goldwin Smith Hall 350',
#   'Tues & Thurs',
#   '1:25pm - 2:40pm',
#   '',
#   'Chiara Formichi (cf398)'),
#  (1254,
#   'FA14',
#   'ASIAN',
#   'ASIAN 2264',
#   'Lecture',
#   '9538',
#   'Rockefeller Hall 127',
#   'Mon, Wed & Fri',
#   '10:10am - 11:00am',
#   '',
#   'Nick Admussen (na347)'),
#  (1255,
#   'FA14',
#   'ASIAN',
#   'ASIAN 2268',
#   'Lecture',
#   '17904',
#   'Rockefeller Hall 122',
#   'Tues & Thurs',
#   '1:25pm - 2:40pm',
#   '',
#   'John Barwick (jsb435)'),
#  (1256,
#   'FA14',
#   'ASIAN',
#   'ASIAN 2298',
#   'Lecture',
#   '15594',
#   'Rockefeller Hall 115',
#   'Tues & Thurs',
#   '8:40am - 9:55am',
#   '',
#   'Keith Taylor (kwt3)'),
#  (1257,
#   'FA14',
#   'ASIAN',
#   'ASIAN 2299',
#   'Lecture',
#   '9025',
#   'Baker Laboratory 219',
#   'Mon & Wed',
#   '11:15am - 12:05pm',
#   '',
#   'Daniel Boucher (djb38)'),
#  (1260,
#   'FA14',
#   'ASIAN',
#   'ASIAN 3321',
#   'Lecture',
#   '8904',
#   'Goldwin Smith Hall G64-Kau Aud',
#   'Tues & Thurs',
#   '1:25pm - 2:40pm',
#   '',
#   'Andrew Mertha (am847)'),
#  (1265,
#   'FA14',
#   'ASIAN',
#   'ASIAN 3331',
#   'Lecture',
#   '9027',
#   'Uris Hall G88',
#   'Tues & Thurs',
#   '10:10am - 11:25am',
#   '',
#   'Arnika Fuhrmann (aif32)'),
#  (1266,
#   'FA14',
#   'ASIAN',
#   'ASIAN 3353',
#   'Lecture',
#   '15686',
#   'Statler Hall 351',
#   'Mon & Wed',
#   '2:55pm - 4:10pm',
#   '',
#   'Daniel Boucher (djb38)'),
#  (1267,
#   'FA14',
#   'ASIAN',
#   'ASIAN 3367',
#   'Lecture',
#   '17433',
#   'McGraw Hall 365',
#   'Mon, Wed & Fri',
#   '1:25pm - 2:15pm',
#   '',
#   'Erick White (ew12)'),
#  (1268,
#   'FA14',
#   'ASIAN',
#   'ASIAN 3383',
#   'Lecture',
#   '8565',
#   'Goldwin Smith Hall G22',
#   'Tues & Thurs',
#   '11:40am - 12:55pm',
#   '',
#   'An-Yi Pan (ap76)'),
#  (1298,
#   'FA14',
#   'ASIAN',
#   'ASIAN 4411',
#   'Lecture',
#   '15577',
#   'Uris Hall 254',
#   'Tues & Thurs',
#   '2:55pm - 4:10pm',
#   '',
#   'John Whitman (jbw2)'),
#  (1301,
#   'FA14',
#   'ASIAN',
#   'ASIAN 4470',
#   'Lecture',
#   '15834',
#   'Rockefeller Hall 104',
#   'Tues & Thurs',
#   '2:55pm - 4:10pm',
#   '',
#   'Naoki Sakai (ns32)'),
#  (1305,
#   'FA14',
#   'ASIAN',
#   'ASIAN 6631',
#   'Lecture',
#   '15613',
#   'Uris Hall G88',
#   'Tues & Thurs',
#   '10:10am - 11:25am',
#   '',
#   'Arnika Fuhrmann (aif32)'),
#  (1321,
#   'FA14',
#   'ASRC',
#   'ASRC 1100',
#   'Lecture',
#   '5841',
#   'Africana Ctr B01',
#   'Mon, Tues, Wed, Thurs & Fri',
#   '9:05am - 9:55am',
#   '',
#   'Happiness Bulugu (hpb36)'),
#  (1322,
#   'FA14',
#   'ASRC',
#   'ASRC 1100',
#   'Lecture',
#   '7918',
#   'Africana Ctr B01',
#   'Mon, Tues, Wed, Thurs & Fri',
#   '10:10am - 11:00am',
#   '',
#   'Happiness Bulugu (hpb36)'),
#  (1325,
#   'FA14',
#   'ASRC',
#   'ASRC 1113',
#   'Lecture',
#   '9757',
#   'NONE',
#   'Mon, Tues, Wed, Thurs & Fri',
#   '11:35am - 12:25pm',
#   '',
#   'Dick Feldman (rf10)'),
#  (1326,
#   'FA14',
#   'ASRC',
#   'ASRC 1117',
#   'Lecture',
#   '18006',
#   'Noyes Lodge - Beebe Lake G06',
#   'Mon, Tues, Wed & Thurs',
#   '12:00pm - 12:50pm',
#   '',
#   'Dick Feldman (rf10)'),
#  (1333,
#   'FA14',
#   'ASRC',
#   'ASRC 1500',
#   'Lecture',
#   '16807',
#   'NONE',
#   'Mon & Wed',
#   '2:55pm - 4:10pm',
#   '',
#   'Riche Richardson (rdr83)'),
#  (1334,
#   'FA14',
#   'ASRC',
#   'ASRC 1590',
#   'Lecture',
#   '15711',
#   'Uris Hall 262',
#   'Mon & Wed',
#   '11:15am - 12:05pm',
#   '',
#   'Judith Byfield (jab632)'),
#  (1337,
#   'FA14',
#   'ASRC',
#   'ASRC 1790',
#   'Lecture',
#   '17115',
#   'Mcgraw Hall 165',
#   'Tues & Thurs',
#   '10:10am - 11:25am',
#   '',
#   'Ernesto Bassi Arevalo (eb577)'),
#  (1340,
#   'FA14',
#   'ASRC',
#   'ASRC 2020',
#   'Lecture',
#   '16833',
#   'Africana Ctr B01',
#   'Tues & Thurs',
#   '1:25pm - 2:40pm',
#   '',
#   'Olufemi Taiwo (ot48)'),
#  (1343,
#   'FA14',
#   'ASRC',
#   'ASRC 2110',
#   'Lecture',
#   '6857',
#   'Uris Hall 382',
#   'Mon, Tues, Wed, Thurs & Fri',
#   '9:05am - 9:55am',
#   '',
#   'Adeolu Ademoyo (aaa54)'),
#  (1346,
#   'FA14',
#   'ASRC',
#   'ASRC 2674',
#   'Lecture',
#   '15605',
#   'Malott Hall 253',
#   'Mon & Wed',
#   '10:10am - 11:00am',
#   '',
#   'Drew Kinney (dhk54)'),
#  (1353,
#   'FA14',
#   'ASRC',
#   'ASRC 2950',
#   'Lecture',
#   '17329',
#   'Uris Hall G88',
#   'Tues & Thurs',
#   '11:40am - 12:55pm',
#   '',
#   'Danielle Terrazas Williams (dlw42)'),
#  (1356,
#   'FA14',
#   'ASRC',
#   'ASRC 3110',
#   'Lecture',
#   '8193',
#   'Uris Hall G24',
#   'Mon & Wed',
#   '7:30pm - 9:25pm',
#   '',
#   'Adeolu Ademoyo (aaa54)'),
#  (1357,
#   'FA14',
#   'ASRC',
#   'ASRC 3113',
#   'Lecture',
#   '9763',
#   'NONE',
#   'Mon & Wed',
#   '2:30pm - 3:45pm',
#   '',
#   'None'),
#  (1358,
#   'FA14',
#   'ASRC',
#   'ASRC 3505',
#   'Lecture',
#   '16351',
#   'Goldwin Smith Hall G22',
#   'Tues & Thurs',
#   '1:25pm - 2:40pm',
#   '',
#   'Cheryl Finley (cf86)'),
#  (1363,
#   'FA14',
#   'ASRC',
#   'ASRC 4606',
#   'Lecture',
#   '8601',
#   'Africana Ctr B07',
#   'Mon',
#   '10:10am - 12:35pm',
#   '',
#   "N'Dri Assie-Lumumba (na12)"),
#  (1392,
#   'FA14',
#   'ASRC',
#   'ASRC 6066',
#   'Lecture',
#   '17977',
#   'Africana Ctr B07',
#   'Mon',
#   '10:10am - 12:35pm',
#   '',
#   "N'Dri Assie-Lumumba (na12)"),
#  (1431,
#   'FA14',
#   'ASTRO',
#   'ASTRO 1101',
#   'Lecture',
#   '6435',
#   'Uris Hall G01',
#   'Mon, Wed & Fri',
#   '11:15am - 12:05pm',
#   '',
#   'James Lloyd (jl554)'),
#  (1443,
#   'FA14',
#   'ASTRO',
#   'ASTRO 1103',
#   'Lecture',
#   '6639',
#   'Uris Hall G01',
#   'Mon, Wed & Fri',
#   '11:15am - 12:05pm',
#   '',
#   'James Lloyd (jl554)'),
#  (1458,
#   'FA14',
#   'ASTRO',
#   'ASTRO 1195',
#   'Lecture',
#   '8425',
#   'Space Sciences Building 105',
#   'Tues & Thurs',
#   '1:25pm - 2:15pm',
#   '',
#   'Gordon Stacey (gjs12)'),
#  (1460,
#   'FA14',
#   'ASTRO',
#   'ASTRO 1700',
#   'Lecture',
#   '7940',
#   'Uris Hall G01',
#   'Mon & Wed',
#   '10:10am - 11:00am',
#   '',
#   'Mary Norton (mbn1)'),
#  (1466,
#   'FA14',
#   'ASTRO',
#   'ASTRO 2202',
#   'Lecture',
#   '16268',
#   'Space Sciences Building 105',
#   'Tues & Thurs',
#   '10:10am - 11:25am',
#   '',
#   'Alexander Hayes (agh4)'),
#  (1467,
#   'FA14',
#   'ASTRO',
#   'ASTRO 2212',
#   'Lecture',
#   '16274',
#   'Space Sciences Building 105',
#   'Tues & Thurs',
#   '11:40am - 12:55pm',
#   '',
#   'Donald Campbell (dbc7)'),
#  (1468,
#   'FA14',
#   'ASTRO',
#   'ASTRO 2290',
#   'Lecture',
#   '16059',
#   'Space Sciences Building 301',
#   'Tues & Thurs',
#   '1:25pm - 2:40pm',
#   '',
#   'David Chernoff (dfc8)'),
#  (1469,
#   'FA14',
#   'ASTRO',
#   'ASTRO 2299',
#   'Lecture',
#   '16062',
#   'Space Sciences Building 622',
#   'Mon & Wed',
#   '2:55pm - 4:10pm',
#   '',
#   'Shami Chatterjee (sc99)'),
#  (1470,
#   'FA14',
#   'ASTRO',
#   'ASTRO 4410',
#   'Lecture',
#   '5854',
#   'Space Sciences Building 605',
#   'Wed',
#   '4:30pm - 5:30pm',
#   'Aug 27, 2014',
#   'Donald Barry (djb49)'),
#  (1471,
#   'FA14',
#   'ASTRO',
#   'ASTRO 4431',
#   'Lecture',
#   '5798',
#   'Space Sciences Building 622',
#   'Tues & Thurs',
#   '1:25pm - 2:40pm',
#   '',
#   'Jonathan Lunine (jil45)'),
#  (1472,
#   'FA14',
#   'ASTRO',
#   'ASTRO 4445',
#   'Lecture',
#   '6488',
#   'Rockefeller Hall 104',
#   'Tues & Thurs',
#   '1:25pm - 2:40pm',
#   '',
#   'Thomas Hartman (th447)'),
#  (1509,
#   'FA14',
#   'ASTRO',
#   'ASTRO 6509',
#   'Lecture',
#   '16025',
#   'Rockefeller Hall 105',
#   'Tues & Thurs',
#   '1:25pm - 2:40pm',
#   '',
#   'Eanna Flanagan (eef3)'),
#  (1510,
#   'FA14',
#   'ASTRO',
#   'ASTRO 6560',
#   'Lecture',
#   '16267',
#   'Space Sciences Building 622',
#   'Tues & Thurs',
#   '10:10am - 11:25am',
#   '',
#   'Ira Wasserman (imw2)'),
#  (1511,
#   'FA14',
#   'ASTRO',
#   'ASTRO 6575',
#   'Lecture',
#   '16270',
#   'Space Sciences Building 301',
#   'Tues & Thurs',
#   '11:40am - 12:55pm',
#   '',
#   'Peter Gierasch (pjg10)'),
#  (1512,
#   'FA14',
#   'ASTRO',
#   'ASTRO 6590',
#   'Lecture',
#   '16272',
#   'Space Sciences Building 301',
#   'Mon & Wed',
#   '2:55pm - 4:10pm',
#   '',
#   'Martha Haynes (mph6)'),
#  (1550,
#   'FA14',
#   'BEE',
#   'BEE 1510',
#   'Lecture',
#   '1052',
#   'Riley-Robb Hall 125',
#   'Mon & Wed',
#   '10:10am - 11:25am',
#   '',
#   'C. Anderson (cla28)'),
#  (1555,
#   'FA14',
#   'BEE',
#   'BEE 2510',
#   'Lecture',
#   '1305',
#   'Riley-Robb Hall 105',
#   'Tues & Thurs',
#   '10:10am - 11:25am',
#   '',
#   'Ludmilla Aristilde (la31)'),
#  (1556,
#   'FA14',
#   'BEE',
#   'BEE 2600',
#   'Lecture',
#   '1306',
#   'Riley-Robb Hall 125',
#   'Tues & Thurs',
#   '10:10am - 11:25am',
#   '',
#   'Mingming Wu (mw272)'),
#  (1557,
#   'FA14',
#   'BEE',
#   'BEE 3310',
#   'Lecture',
#   '1348',
#   'Riley-Robb Hall 105',
#   'Mon, Wed & Fri',
#   '10:10am - 11:00am',
#   '',
#   'Kifle Gebremedhin (kgg1)'),
#  (1559,
#   'FA14',
#   'BEE',
#   'BEE 3500',
#   'Lecture',
#   '4418',
#   'Riley-Robb Hall 105',
#   'Mon, Wed & Fri',
#   '11:15am - 12:05pm',
#   '',
#   'Ashim Datta (akd1)'),
#  (1561,
#   'FA14',
#   'BEE',
#   'BEE 4270',
#   'Lecture',
#   '3728',
#   'Riley-Robb Hall 225',
#   'Tues',
#   '9:05am - 9:55am',
#   '',
#   'Larry Geohring (ldg5)'),
#  (1563,
#   'FA14',
#   'BEE',
#   'BEE 4550',
#   'Lecture',
#   '4673',
#   'Riley-Robb Hall 225',
#   'Wed & Fri',
#   '8:40am - 9:55am',
#   '',
#   'Mingming Wu (mw272)'),
#  (1564,
#   'FA14',
#   'BEE',
#   'BEE 4550',
#   'Lecture',
#   '4674',
#   'Riley-Robb Hall 225',
#   'Wed & Fri',
#   '8:40am - 9:55am',
#   '',
#   'Mingming Wu (mw272)'),
#  (1566,
#   'FA14',
#   'BEE',
#   'BEE 4590',
#   'Lecture',
#   '1350',
#   'Riley-Robb Hall 105',
#   'Tues & Thurs',
#   '1:25pm - 2:40pm',
#   '',
#   'Katie Edwards (kae24)'),
#  (1567,
#   'FA14',
#   'BEE',
#   'BEE 4600',
#   'Lecture',
#   '1351',
#   'Riley-Robb Hall 225',
#   'Tues & Thurs',
#   '10:10am - 11:25am',
#   '',
#   'John March (jcm224)'),
#  (1568,
#   'FA14',
#   'BEE',
#   'BEE 4640',
#   'Lecture',
#   '16622',
#   'Riley-Robb Hall 105',
#   'Mon, Wed & Fri',
#   '12:20pm - 1:10pm',
#   '',
#   'Jean Hunter (jbh5)'),
#  (1569,
#   'FA14',
#   'BEE',
#   'BEE 4730',
#   'Lecture',
#   '1576',
#   'Riley-Robb Hall B15',
#   'Tues & Thurs',
#   '10:10am - 11:00am',
#   '',
#   'Todd Walter (mtw5)'),
#  (1571,
#   'FA14',
#   'BEE',
#   'BEE 4750',
#   'Lecture',
#   '1069',
#   'Riley-Robb Hall 105',
#   'Tues & Thurs',
#   '11:40am - 12:55pm',
#   '',
#   'Douglas Haith (dah13)'),
#  (1572,
#   'FA14',
#   'BEE',
#   'BEE 4800',
#   'Lecture',
#   '16665',
#   'Riley-Robb Hall 205',
#   'Tues & Thurs',
#   '1:25pm - 2:40pm',
#   '',
#   'Peter Hess (pgh25)'),
#  (1573,
#   'FA14',
#   'BEE',
#   'BEE 4890',
#   'Lecture',
#   '4677',
#   'Riley-Robb Hall 125',
#   'Mon',
#   '2:30pm - 4:25pm',
#   '',
#   'Michael Timmons (mbt3)'),
#  (1575,
#   'FA14',
#   'BEE',
#   'BEE 4940',
#   'Lecture',
#   '16669',
#   'Riley-Robb Hall B15',
#   'Tues & Thurs',
#   '8:40am - 9:55am',
#   '',
#   'Minglin Ma (mm826)'),
#  (1584,
#   'FA14',
#   'BEE',
#   'BEE 5400',
#   'Lecture',
#   '5065',
#   'NONE',
#   '',
#   'None',
#   '',
#   'Rick Evans (rae27)'),
#  (1611,
#   'FA14',
#   'BEE',
#   'BEE 6550',
#   'Lecture',
#   '5048',
#   'Riley-Robb Hall 225',
#   'Wed & Fri',
#   '8:40am - 9:55am',
#   '',
#   'Mingming Wu (mw272)'),
#  (1612,
#   'FA14',
#   'BEE',
#   'BEE 6550',
#   'Lecture',
#   '5033',
#   'Riley-Robb Hall 225',
#   'Wed & Fri',
#   '8:40am - 9:55am',
#   '',
#   'Mingming Wu (mw272)'),
#  (1614,
#   'FA14',
#   'BEE',
#   'BEE 6940',
#   'Lecture',
#   '18188',
#   'Snee Hall Geological Sci 4116',
#   'Thurs',
#   '1:00pm - 4:00pm',
#   '',
#   'Lawrence Cathles (lmc19)'),
#  (1640,
#   'FA14',
#   'BEE',
#   'BEE 7000',
#   'Lecture',
#   '1352',
#   'Riley-Robb Hall 205',
#   'Mon',
#   '10:10am - 11:00am',
#   'Aug 26 - Oct 20, 2014',
#   'John March (jcm224)'),
#  (1690,
#   'FA14',
#   'BENGL',
#   'BENGL 1101',
#   'Lecture',
#   '8625',
#   'Noyes Lodge - Beebe Lake G03',
#   'Mon & Wed',
#   '10:10am - 11:00am',
#   '',
#   'Sreemati Mukherjee (sm138)'),
#  (1692,
#   'FA14',
#   'BENGL',
#   'BENGL 2201',
#   'Lecture',
#   '6241',
#   'Noyes Lodge - Beebe Lake G03',
#   'Mon',
#   '1:25pm - 2:15pm',
#   '',
#   'Sreemati Mukherjee (sm138)'),
#  (1695,
#   'FA14',
#   'BIOAP',
#   'BIOAP 2140',
#   'Lecture',
#   '16799',
#   'Stimson Hall G01',
#   'Tues & Thurs',
#   '8:40am - 9:55am',
#   '',
#   'Joanne Fortune (jf11)'),
#  (1696,
#   'FA14',
#   'BIOAP',
#   'BIOAP 3110',
#   'Lecture',
#   '1353',
#   'Bradfield Hall 101',
#   'Mon, Wed & Fri',
#   '11:15am - 12:05pm',
#   '',
#   'Ellis Loew (erl1)'),
#  (1697,
#   'FA14',
#   'BIOAP',
#   'BIOAP 3190',
#   'Lecture',
#   '1087',
#   'Vet Research Tower T1003-LH3',
#   'Thurs',
#   '12:20pm - 1:10pm',
#   '',
#   'Ellis Loew (erl1)'),
#  (1702,
#   'FA14',
#   'BIOAP',
#   'BIOAP 4270',
#   'Lecture',
#   '3786',
#   'Morrison Hall 164',
#   'Mon, Wed & Fri',
#   '9:05am - 9:55am',
#   '',
#   'Susan Quirk (smq1)'),
#  (1708,
#   'FA14',
#   'BIOEE',
#   'BIOEE 1540',
#   'Lecture',
#   '1321',
#   'Bailey Hall 101',
#   'Mon, Wed & Fri',
#   '11:15am - 12:05pm',
#   '',
#   'Bruce Monger (bcm3)'),
#  (1709,
#   'FA14',
#   'BIOEE',
#   'BIOEE 1560',
#   'Lecture',
#   '3882',
#   'Bailey Hall 101',
#   'Mon, Wed & Fri',
#   '11:15am - 12:05pm',
#   '',
#   'Bruce Monger (bcm3)'),
#  (1716,
#   'FA14',
#   'BIOEE',
#   'BIOEE 1610',
#   'Lecture',
#   '1209',
#   'Plant Science Building 233',
#   'Tues & Thurs',
#   '1:25pm - 2:15pm',
#   '',
#   'Alexander Flecker (asf3)'),
#  (1733,
#   'FA14',
#   'BIOEE',
#   'BIOEE 1780',
#   'Lecture',
#   '1219',
#   'Kennedy Hall 116-Call Aud',
#   'Mon, Wed & Fri',
#   '3:35pm - 4:25pm',
#   '',
#   'Brian Lazzaro (bl89)'),
#  (1752,
#   'FA14',
#   'BIOEE',
#   'BIOEE 2070',
#   'Lecture',
#   '1296',
#   'Baker Laboratory 219',
#   'Tues & Thurs',
#   '1:25pm - 2:15pm',
#   '',
#   'Gregory Graffin (gwg1)'),
#  (1756,
#   'FA14',
#   'BIOEE',
#   'BIOEE 2670',
#   'Lecture',
#   '15939',
#   'Fernow Hall G24',
#   'Mon & Wed',
#   '10:10am - 11:00am',
#   '',
#   'Amanda Rodewald (adr79)'),
#  (1757,
#   'FA14',
#   'BIOEE',
#   'BIOEE 2670',
#   'Lecture',
#   '15940',
#   'Fernow Hall G24',
#   'Mon & Wed',
#   '10:10am - 11:00am',
#   '',
#   'Amanda Rodewald (adr79)'),
#  (1759,
#   'FA14',
#   'BIOEE',
#   'BIOEE 3610',
#   'Lecture',
#   '4388',
#   'Caldwell Hall 100',
#   'Mon, Wed & Fri',
#   '10:10am - 11:00am',
#   '',
#   'Stephen Ellner (spe2)'),
#  (1762,
#   'FA14',
#   'BIOEE',
#   'BIOEE 3611',
#   'Lecture',
#   '4638',
#   'NONE',
#   '',
#   'None',
#   '',
#   'Anurag Agrawal (aa337)'),
#  (1764,
#   'FA14',
#   'BIOEE',
#   'BIOEE 4550',
#   'Lecture',
#   '16150',
#   'Comstock Hall-Academic II B106',
#   'Tues & Thurs',
#   '9:05am - 9:55am',
#   '',
#   'Jennifer Thaler (jst37)'),
#  (1768,
#   'FA14',
#   'BIOEE',
#   'BIOEE 4620',
#   'Lecture',
#   '15799',
#   'Corson-Mudd A106',
#   'Mon & Wed',
#   '2:30pm - 3:20pm',
#   '',
#   'Charles Greene (chg2)'),
#  (1771,
#   'FA14',
#   'BIOEE',
#   'BIOEE 4690',
#   'Lecture',
#   '4628',
#   'Corson-Mudd A409',
#   'Tues & Thurs',
#   '1:25pm - 2:40pm',
#   '',
#   'Alison Power (agp4)'),
#  (1772,
#   'FA14',
#   'BIOEE',
#   'BIOEE 4760',
#   'Lecture',
#   '15695',
#   'Corson-Mudd A409',
#   'Mon, Wed & Fri',
#   '10:10am - 11:00am',
#   '',
#   'John Friel (jpf19)'),
#  (1774,
#   'FA14',
#   'BIOEE',
#   'BIOEE 4940',
#   'Lecture',
#   '17908',
#   'NONE',
#   '',
#   'None',
#   '',
#   'Robert Howarth (rwh2)'),
#  (1775,
#   'FA14',
#   'BIOEE',
#   'BIOEE 4940',
#   'Lecture',
#   '18186',
#   'Alice H. Cook House 106',
#   'Thurs',
#   '6:00pm - 8:00pm',
#   '',
#   'Andr̩ Dhondt (aad4)'),
#  (1776,
#   'FA14',
#   'BIOEE',
#   'BIOEE 4940',
#   'Lecture',
#   '18399',
#   'Corson-Mudd A409',
#   'Mon',
#   '4:30pm - 6:00pm',
#   '',
#   'David Winkler (dww4)'),
#  (1784,
#   'FA14',
#   'BIOEE',
#   'BIOEE 7670',
#   'Lecture',
#   '1300',
#   'Corson-Mudd A409',
#   'Tues & Thurs',
#   '10:10am - 12:05pm',
#   '',
#   'Monica Geber (mag9)'),
#  (1828,
#   'FA14',
#   'BIOG',
#   'BIOG 1045',
#   'Lecture',
#   '5085',
#   'Stimson Hall 206',
#   'Mon',
#   '1:25pm - 2:20pm',
#   '',
#   'Martha Taylor (mrt2)'),
#  (1829,
#   'FA14',
#   'BIOG',
#   'BIOG 1140',
#   'Lecture',
#   '4135',
#   'Kennedy Hall 116-Call Aud',
#   'Tues & Thurs',
#   '11:40am - 12:55pm',
#   '',
#   'Michael Scanlon (mjs298)'),
#  (1840,
#   'FA14',
#   'BIOG',
#   'BIOG 1440',
#   'Lecture',
#   '4108',
#   'Uris Hall G01',
#   'Mon & Wed',
#   '9:05am - 9:55am',
#   '',
#   'Ellis Loew (erl1)'),
#  (1859,
#   'FA14',
#   'BIOG',
#   'BIOG 1445',
#   'Lecture',
#   '5053',
#   'Uris Hall G01',
#   'Tues',
#   '9:05am - 9:55am',
#   '',
#   'Darlene Campbell (dc78)'),
#  (1860,
#   'FA14',
#   'BIOG',
#   'BIOG 1445',
#   'Lecture',
#   '5054',
#   'Stimson Hall 206',
#   'Tues',
#   '7:30pm - 8:20pm',
#   '',
#   'Darlene Campbell (dc78)'),
#  (1861,
#   'FA14',
#   'BIOG',
#   'BIOG 1500',
#   'Lecture',
#   '4107',
#   'Kennedy Hall 116-Call Aud',
#   'Tues',
#   '9:05am - 9:55am',
#   '',
#   'Mark Sarvary (mas245)'),
#  (1886,
#   'FA14',
#   'BIOG',
#   'BIOG 2000',
#   'Lecture',
#   '18200',
#   'NONE',
#   '',
#   'None',
#   '',
#   'Kerry Shaw (kls4)'),
#  (1887,
#   'FA14',
#   'BIOG',
#   'BIOG 2000',
#   'Lecture',
#   '18560',
#   'NONE',
#   '',
# ...
#   '10:10am - 12:05pm',
#   '',
#   'Troy Richardson (tar37)'),
#  (4737,
#   'FA14',
#   'ENGL',
#   'ENGL 2006',
#   'Lecture',
#   '17048',
#   'Lincoln Hall B20',
#   'Tues & Thurs',
#   '3:35pm - 4:25pm',
#   '',
#   'Tom McEnaney (tpm88)'),
#  (4740,
#   'FA14',
#   'ENGL',
#   'ENGL 2010',
#   'Lecture',
#   '6115',
#   'Rockefeller Hall 122',
#   'Mon & Wed',
#   '11:15am - 12:05pm',
#   '',
#   'Andrew Galloway (asg6)'),
#  (4744,
#   'FA14',
#   'ENGL',
#   'ENGL 2035',
#   'Lecture',
#   '9536',
#   'Goldwin Smith Hall 142',
#   'Mon, Wed & Fri',
#   '11:15am - 12:05pm',
#   '',
#   'Anindita Banerjee (ab425)'),
#  (4745,
#   'FA14',
#   'ENGL',
#   'ENGL 2170',
#   'Lecture',
#   '8483',
#   'Morrill Hall 111',
#   'Mon, Wed & Fri',
#   '10:10am - 11:00am',
#   '',
#   'Wayne Harbert (weh2)'),
#  (4746,
#   'FA14',
#   'ENGL',
#   'ENGL 2270',
#   'Lecture',
#   '7136',
#   'Goldwin Smith Hall 142',
#   'Mon, Wed & Fri',
#   '12:20pm - 1:10pm',
#   '',
#   'Barbara Correll (bc21)'),
#  (4747,
#   'FA14',
#   'ENGL',
#   'ENGL 2350',
#   'Lecture',
#   '9043',
#   'Malott Hall 228-Bache Aud',
#   'Tues & Thurs',
#   '1:25pm - 2:40pm',
#   '',
#   'Elisha Cohn (ejc244)'),
#  (4750,
#   'FA14',
#   'ENGL',
#   'ENGL 2675',
#   'Lecture',
#   '16876',
#   'Rockefeller Hall 104',
#   'Mon, Wed & Fri',
#   '10:10am - 11:00am',
#   '',
#   'Jeremy Braddock (jb358)'),
#  (4751,
#   'FA14',
#   'ENGL',
#   'ENGL 2740',
#   'Lecture',
#   '8500',
#   'Uris Hall G26',
#   'Mon, Wed & Fri',
#   '11:15am - 12:05pm',
#   '',
#   'Thomas Hill (tdh1)'),
#  (4752,
#   'FA14',
#   'ENGL',
#   'ENGL 2780',
#   'Lecture',
#   '15915',
#   'Morrill Hall 106',
#   'Tues & Thurs',
#   '11:40am - 12:55pm',
#   '',
#   'Masha Raskolnikov (mr283)'),
#  (4753,
#   'FA14',
#   'ENGL',
#   'ENGL 2790',
#   'Lecture',
#   '16458',
#   'Rockefeller Hall 115',
#   'Tues & Thurs',
#   '11:40am - 12:55pm',
#   '',
#   'Joanie Mackowski (jm948)'),
#  (4774,
#   'FA14',
#   'ENGL',
#   'ENGL 2960',
#   'Lecture',
#   '15591',
#   'Morrill Hall 226F',
#   'Tues & Thurs',
#   '1:25pm - 2:40pm',
#   '',
#   'John Bowers (jsb2)'),
#  (4775,
#   'FA14',
#   'ENGL',
#   'ENGL 3021',
#   'Lecture',
#   '17040',
#   'Rockefeller Hall 122',
#   'Mon, Wed & Fri',
#   '1:25pm - 2:15pm',
#   '',
#   'Cathy Caruth (cc694)'),
#  (4779,
#   'FA14',
#   'ENGL',
#   'ENGL 3390',
#   'Lecture',
#   '8498',
#   'Goldwin Smith Hall 236',
#   'Mon, Wed & Fri',
#   '9:05am - 9:55am',
#   '',
#   'Harry Shaw (hes3)'),
#  (4781,
#   'FA14',
#   'ENGL',
#   'ENGL 3500',
#   'Lecture',
#   '8955',
#   'Goldwin Smith Hall 236',
#   'Tues & Thurs',
#   '1:25pm - 2:40pm',
#   '',
#   'Daniel Schwarz (drs6)'),
#  (4782,
#   'FA14',
#   'ENGL',
#   'ENGL 3550',
#   'Lecture',
#   '15950',
#   'Rockefeller Hall 132',
#   'Mon & Wed',
#   '7:30pm - 8:45pm',
#   '',
#   'Ellis Hanson (eh36)'),
#  (4783,
#   'FA14',
#   'ENGL',
#   'ENGL 3672',
#   'Lecture',
#   '16459',
#   'Goldwin Smith Hall G22',
#   'Tues & Thurs',
#   '10:10am - 11:25am',
#   '',
#   'Ananda Cohen Suarez (aic42)'),
#  (4794,
#   'FA14',
#   'ENGL',
#   'ENGL 4291',
#   'Lecture',
#   '9743',
#   'Washington, DC',
#   'Fri',
#   '10:00am - 12:00pm',
#   '',
#   "John O'Connor (jo267)"),
#  (4981,
#   'FA14',
#   'ENGL',
#   'ENGL 6785',
#   'Lecture',
#   '16017',
#   'Morrill Hall 226F',
#   'Tues & Thurs',
#   '1:25pm - 2:40pm',
#   '',
#   'John Bowers (jsb2)'),
#  (5086,
#   'FA14',
#   'ENGRD',
#   'ENGRD 2020',
#   'Lecture',
#   '11598',
#   'Phillips Hall 101',
#   'Mon, Wed & Fri',
#   '10:10am - 11:00am',
#   '',
#   'Wolfgang Sachse (whs3)'),
#  (5087,
#   'FA14',
#   'ENGRD',
#   'ENGRD 2020',
#   'Lecture',
#   '11599',
#   'Phillips Hall 101',
#   'Mon, Wed & Fri',
#   '11:15am - 12:05pm',
#   '',
#   'Joseph Burns (jab16)'),
#  (5127,
#   'FA14',
#   'ENGRD',
#   'ENGRD 2100',
#   'Lecture',
#   '11278',
#   'Thurston Hall 205',
#   'Mon & Wed',
#   '8:40am - 9:55am',
#   '',
#   'Ehsan Afshari (ea85)'),
#  (5135,
#   'FA14',
#   'ENGRD',
#   'ENGRD 2110',
#   'Lecture',
#   '11644',
#   'Statler Hall 185-Aud',
#   'Tues & Thurs',
#   '10:10am - 11:00am',
#   '',
#   'David Gries (djg17)'),
#  (5150,
#   'FA14',
#   'ENGRD',
#   'ENGRD 2112',
#   'Lecture',
#   '16521',
#   'Thurston Hall 205',
#   'Tues & Thurs',
#   '10:10am - 11:00am',
#   '',
#   'Andrew Myers (acm22)'),
#  (5155,
#   'FA14',
#   'ENGRD',
#   'ENGRD 2190',
#   'Lecture',
#   '11285',
#   'Olin Hall 245',
#   'Mon, Wed & Fri',
#   '10:10am - 11:00am',
#   '',
#   'Thomas Duncan (tmd10)'),
#  (5158,
#   'FA14',
#   'ENGRD',
#   'ENGRD 2190',
#   'Lecture',
#   '17663',
#   'Olin Hall 218',
#   'Mon, Wed & Fri',
#   '10:10am - 11:00am',
#   '',
#   'Paulette Clancy (pqc1)'),
#  (5161,
#   'FA14',
#   'ENGRD',
#   'ENGRD 2210',
#   'Lecture',
#   '11288',
#   'Olin Hall 155',
#   'Mon, Wed & Fri',
#   '9:05am - 9:55am',
#   '',
#   'Elizabeth Fisher (emf4)'),
#  (5168,
#   'FA14',
#   'ENGRD',
#   'ENGRD 2300',
#   'Lecture',
#   '11551',
#   'Kimball Hall B11',
#   'Tues & Thurs',
#   '11:40am - 12:55pm',
#   '',
#   'Edward Suh (gs272)'),
#  (5173,
#   'FA14',
#   'ENGRD',
#   'ENGRD 2510',
#   'Lecture',
#   '11593',
#   'Riley-Robb Hall 105',
#   'Tues & Thurs',
#   '10:10am - 11:25am',
#   '',
#   'Ludmilla Aristilde (la31)'),
#  (5174,
#   'FA14',
#   'ENGRD',
#   'ENGRD 2600',
#   'Lecture',
#   '11594',
#   'Riley-Robb Hall 125',
#   'Tues & Thurs',
#   '10:10am - 11:25am',
#   '',
#   'Mingming Wu (mw272)'),
#  (5175,
#   'FA14',
#   'ENGRD',
#   'ENGRD 2610',
#   'Lecture',
#   '11497',
#   'Kimball Hall B11',
#   'Tues & Thurs',
#   '10:10am - 11:25am',
#   '',
#   'Shefford Baker (spb14)'),
#  (5179,
#   'FA14',
#   'ENGRD',
#   'ENGRD 2640',
#   'Lecture',
#   '12950',
#   'Clark Hall 247',
#   'Mon',
#   '2:30pm - 4:25pm',
#   '',
#   'Gregory Fuchs (gdf9)'),
#  (5184,
#   'FA14',
#   'ENGRD',
#   'ENGRD 2700',
#   'Lecture',
#   '11795',
#   'Olin Hall 155',
#   'Tues & Thurs',
#   '1:25pm - 2:40pm',
#   '',
#   'Jacob Feldman (jbf232)'),
#  (5191,
#   'FA14',
#   'ENGRD',
#   'ENGRD 3100',
#   'Lecture',
#   '12091',
#   'Upson Hall B17',
#   'Mon & Wed',
#   '2:55pm - 4:10pm',
#   '',
#   'Carl Poitras (cbp8)'),
#  (5206,
#   'FA14',
#   'ENGRG',
#   'ENGRG 1021',
#   'Lecture',
#   '12126',
#   'Olin Hall 145',
#   'Wed',
#   '7:00pm - 9:00pm',
#   '',
#   'Tracey Brant (tlb10)'),
#  (5263,
#   'FA14',
#   'ENGRG',
#   'ENGRG 2500',
#   'Lecture',
#   '12810',
#   'Phillips Hall 407',
#   'Mon & Wed',
#   '10:10am - 11:00am',
#   '',
#   'Ronald Kline (rrk1)'),
#  (5266,
#   'FA14',
#   'ENGRG',
#   'ENGRG 3600',
#   'Lecture',
#   '15862',
#   'Phillips Hall 213',
#   'Tues & Thurs',
#   '2:55pm - 4:10pm',
#   '',
#   'Park Doing (pad9)'),
#  (5268,
#   'FA14',
#   'ENGRG',
#   'ENGRG 4610',
#   'Lecture',
#   '11399',
#   'Phillips Hall 203',
#   'Mon, Wed & Fri',
#   '10:10am - 11:00am',
#   '',
#   'John Richard Callister (jc62)'),
#  (5270,
#   'FA14',
#   'ENGRG',
#   'ENGRG 4910',
#   'Lecture',
#   '11395',
#   'NONE',
#   '',
#   'None',
#   '',
#   'Carl Batt (cab10)'),
#  (5273,
#   'FA14',
#   'ENGRI',
#   'ENGRI 1100',
#   'Lecture',
#   '12535',
#   'Baker Laboratory 135',
#   'Tues & Thurs',
#   '10:10am - 11:00am',
#   '',
#   'Chris Xu (cx10)'),
#  (5278,
#   'FA14',
#   'ENGRI',
#   'ENGRI 1101',
#   'Lecture',
#   '11267',
#   'Frank H T Rhodes Hall 471',
#   'Tues & Thurs',
#   '10:10am - 11:00am',
#   '',
#   'Robert Bland (rgb6)'),
#  (5282,
#   'FA14',
#   'ENGRI',
#   'ENGRI 1110',
#   'Lecture',
#   '11264',
#   'Thurston Hall 205',
#   'Mon, Wed & Fri',
#   '10:10am - 11:00am',
#   '',
#   'Christopher Umbach (ccu1)'),
#  (5283,
#   'FA14',
#   'ENGRI',
#   'ENGRI 1120',
#   'Lecture',
#   '11262',
#   'Olin Hall 245',
#   'Tues & Thurs',
#   '9:05am - 9:55am',
#   '',
#   'Jeffrey Varner (jdv27)'),
#  (5286,
#   'FA14',
#   'ENGRI',
#   'ENGRI 1160',
#   'Lecture',
#   '11401',
#   'Hollister Hall 366',
#   'Tues & Thurs',
#   '10:10am - 11:25am',
#   '',
#   'Christopher Earls (cje23)'),
#  (5287,
#   'FA14',
#   'ENGRI',
#   'ENGRI 1170',
#   'Lecture',
#   '11272',
#   'Olin Hall 245',
#   'Tues & Thurs',
#   '11:15am - 12:05pm',
#   '',
#   'Hadas Ritz (hr32)'),
#  (5292,
#   'FA14',
#   'ENGRI',
#   'ENGRI 1190',
#   'Lecture',
#   '11277',
#   'Hollister Hall 110',
#   'Tues & Thurs',
#   '11:40am - 12:55pm',
#   '',
#   'Delphine Gourdon (dg434)'),
#  (5293,
#   'FA14',
#   'ENGRI',
#   'ENGRI 1200',
#   'Lecture',
#   '12315',
#   'Physical Sciences Building 120',
#   'Tues & Thurs',
#   '10:10am - 11:00am',
#   '',
#   'Frank Wise (fww1)'),
#  (5298,
#   'FA14',
#   'ENGRI',
#   'ENGRI 1610',
#   'Lecture',
#   '17762',
#   'Lincoln Hall B20',
#   'Tues & Thurs',
#   '1:25pm - 2:40pm',
#   '',
#   'Graeme Bailey (gob1)'),
#  (5299,
#   'FA14',
#   'ENGRI',
#   'ENGRI 1620',
#   'Lecture',
#   '12879',
#   'Milstein Hall 101',
#   'Tues & Thurs',
#   '11:15am - 12:05pm',
#   '',
#   'Donald Greenberg (dpg5)'),
#  (5300,
#   'FA14',
#   'ENGRI',
#   'ENGRI 1820',
#   'Lecture',
#   '13055',
#   'Phillips Hall 307',
#   'Mon & Fri',
#   '10:10am - 11:00am',
#   '',
#   'Amit Lal (al274)'),
#  (5304,
#   'FA14',
#   'ENTOM',
#   'ENTOM 2100',
#   'Lecture',
#   '15650',
#   'M Van Rensselaer Hall G73',
#   'Mon & Wed',
#   '2:30pm - 3:20pm',
#   '',
#   'Marina Caillaud (cmc27)'),
#  (5305,
#   'FA14',
#   'ENTOM',
#   'ENTOM 2100',
#   'Lecture',
#   '15651',
#   'M Van Rensselaer Hall G73',
#   'Mon & Wed',
#   '2:30pm - 3:20pm',
#   '',
#   'Marina Caillaud (cmc27)'),
#  (5312,
#   'FA14',
#   'ENTOM',
#   'ENTOM 2120',
#   'Lecture',
#   '1153',
#   'Comstock Hall-Academic II 2123',
#   'Tues & Thurs',
#   '10:10am - 11:00am',
#   '',
#   'Cole Gilbert (cg23)'),
#  (5315,
#   'FA14',
#   'ENTOM',
#   'ENTOM 2150',
#   'Lecture',
#   '4924',
#   'Corson-Mudd A106',
#   'Wed & Fri',
#   '1:25pm - 2:15pm',
#   '',
#   'Linda Rayor (lsr1)'),
#  (5316,
#   'FA14',
#   'ENTOM',
#   'ENTOM 3070',
#   'Lecture',
#   '16204',
#   'Comstock Hall-Academic II B108',
#   'Tues & Thurs',
#   '12:20pm - 1:10pm',
#   '',
#   'Jeffrey Scott (jgs5)'),
#  (5317,
#   'FA14',
#   'ENTOM',
#   'ENTOM 3150',
#   'Lecture',
#   '4925',
#   'Corson-Mudd A106',
#   'Wed & Fri',
#   '1:25pm - 2:15pm',
#   '',
#   'Linda Rayor (lsr1)'),
#  (5319,
#   'FA14',
#   'ENTOM',
#   'ENTOM 3200',
#   'Lecture',
#   '1011',
#   'Plant Science Building 141',
#   'Mon & Wed',
#   '11:15am - 12:05pm',
#   '',
#   'Andrew Landers (ajl31)'),
#  (5321,
#   'FA14',
#   'ENTOM',
#   'ENTOM 3350',
#   'Lecture',
#   '1318',
#   'Comstock Hall-Academic II B108',
#   'Thurs',
#   '1:25pm - 4:25pm',
#   '',
#   'Linda Rayor (lsr1)'),
#  (5323,
#   'FA14',
#   'ENTOM',
#   'ENTOM 4190',
#   'Lecture',
#   '4316',
#   'Geneva, NY',
#   'Tues & Thurs',
#   '8:30am - 10:30am',
#   '',
#   'David Gadoury (dmg4)'),
#  (5325,
#   'FA14',
#   'ENTOM',
#   'ENTOM 4550',
#   'Lecture',
#   '16148',
#   'Comstock Hall-Academic II B106',
#   'Tues & Thurs',
#   '9:05am - 9:55am',
#   '',
#   'Jennifer Thaler (jst37)'),
#  (5327,
#   'FA14',
#   'ENTOM',
#   'ENTOM 4730',
#   'Lecture',
#   '16373',
#   'Plant Science Building 143',
#   'Tues & Thurs',
#   '2:30pm - 3:45pm',
#   '',
#   'Laurie Drinkwater (led24)'),
#  (5329,
#   'FA14',
#   'ENTOM',
#   'ENTOM 4940',
#   'Lecture',
#   '3757',
#   'NONE',
#   '',
#   'None',
#   '',
#   'None'),
#  (5415,
#   'FA14',
#   'FDSC',
#   'FDSC 1101',
#   'Lecture',
#   '1407',
#   'Stocking Hall 146',
#   'Tues',
#   '1:25pm - 2:15pm',
#   '',
#   'Alicia Orta-Ramirez (ao98)'),
#  (5416,
#   'FA14',
#   'FDSC',
#   'FDSC 1104',
#   'Lecture',
#   '5005',
#   'Stocking Hall 146',
#   'Mon & Wed',
#   '7:30pm - 9:00pm',
#   '',
#   'Kathy Arnink (kja1)'),
#  (5417,
#   'FA14',
#   'FDSC',
#   'FDSC 1104',
#   'Lecture',
#   '17730',
#   'NONE',
#   'Tues & Thurs',
#   '11:40am - 12:55pm',
#   '',
#   'Kathy Arnink (kja1)'),
#  (5418,
#   'FA14',
#   'FDSC',
#   'FDSC 1105',
#   'Lecture',
#   '5061',
#   'Stocking Hall 146',
#   'Thurs',
#   '1:25pm - 2:15pm',
#   '',
#   'Kathy Arnink (kja1)'),
#  (5420,
#   'FA14',
#   'FDSC',
#   'FDSC 2000',
#   'Lecture',
#   '1347',
#   'Malott Hall 228-Bache Aud',
#   'Mon, Wed & Fri',
#   '11:15am - 12:05pm',
#   '',
#   'Robert Parker (rsp3)'),
#  (5421,
#   'FA14',
#   'FDSC',
#   'FDSC 2204',
#   'Lecture',
#   '4037',
#   'Stocking Hall 146',
#   'Mon, Wed & Fri',
#   '12:20pm - 1:10pm',
#   '',
#   'Kathy Arnink (kja1)'),
#  (5423,
#   'FA14',
#   'FDSC',
#   'FDSC 2400',
#   'Lecture',
#   '1016',
#   'Stocking Hall 355',
#   'Tues & Thurs',
#   '1:25pm - 2:15pm',
#   '',
#   'Gavin Sacks (gls9)'),
#  (5425,
#   'FA14',
#   'FDSC',
#   'FDSC 3940',
#   'Lecture',
#   '1409',
#   'Morrison Hall 163',
#   'Mon, Wed & Fri',
#   '12:20pm - 1:10pm',
#   '',
#   'Carl Batt (cab10)'),
#  (5427,
#   'FA14',
#   'FDSC',
#   'FDSC 4020',
#   'Lecture',
#   '1410',
#   'Emerson Hall 135',
#   'Fri',
#   '1:25pm - 3:20pm',
#   '',
#   'Peter Hobbs (ph14)'),
#  (5428,
#   'FA14',
#   'FDSC',
#   'FDSC 4100',
#   'Lecture',
#   '1184',
#   'Stocking Hall 146',
#   'Tues & Thurs',
#   '9:05am - 9:55am',
#   '',
#   'Robin Dando (rd426)'),
#  (5429,
#   'FA14',
#   'FDSC',
#   'FDSC 4100',
#   'Lecture',
#   '1412',
#   'Stocking Hall 146',
#   'Tues & Thurs',
#   '9:05am - 9:55am',
#   '',
#   'Robin Dando (rd426)'),
#  (5431,
#   'FA14',
#   'FDSC',
#   'FDSC 4180',
#   'Lecture',
#   '1186',
#   'Stocking Hall 146',
#   'Mon, Wed & Fri',
#   '9:05am - 9:55am',
#   '',
#   'David Barbano (dmb37)'),
#  (5433,
#   'FA14',
#   'FDSC',
#   'FDSC 4210',
#   'Lecture',
#   '1181',
#   'Stocking Hall 146',
#   'Mon, Wed & Fri',
#   '11:15am - 12:05pm',
#   '',
#   'Syed Rizvi (ssr3)'),
#  (5435,
#   'FA14',
#   'FDSC',
#   'FDSC 4230',
#   'Lecture',
#   '1187',
#   'Morrison Hall 334',
#   'Tues & Thurs',
#   '11:15am - 12:05pm',
#   '',
#   'Steven Mulvaney (sjm7)'),
#  (5437,
#   'FA14',
#   'FDSC',
#   'FDSC 4500',
#   'Lecture',
#   '4986',
#   'Stocking Hall 146',
#   'Tues & Thurs',
#   '10:10am - 11:00am',
#   '',
#   'Patricia Howe (pah237)'),
#  (5439,
#   'FA14',
#   'FDSC',
#   'FDSC 4940',
#   'Lecture',
#   '3444',
#   'Stocking Hall 148',
#   'Tues, Wed & Thurs',
#   '8:00am - 5:00pm',
#   'Oct 14 - Oct 16, 2014',
#   'Martin Wiedmann (mw16)'),
#  (5440,
#   'FA14',
#   'FDSC',
#   'FDSC 4940',
#   'Lecture',
#   '18203',
#   'Stocking Hall 148',
#   'Tues, Wed & Thurs',
#   '8:00am - 5:00pm',
#   'Oct 21 - Oct 23, 2014',
#   'Martin Wiedmann (mw16)'),
#  (5441,
#   'FA14',
#   'FDSC',
#   'FDSC 4940',
#   'Lecture',
#   '18204',
#   'Stocking Hall 148',
#   'Mon',
#   '8:00am - 5:00pm',
#   'Oct 27, 2014',
#   'Martin Wiedmann (mw16)'),
#  (5442,
#   'FA14',
#   'FDSC',
#   'FDSC 4940',
#   'Lecture',
#   '18205',
#   'Stocking Hall 148',
#   'Tues & Wed',
#   '8:00am - 5:00pm',
#   'Oct 28 - Oct 29, 2014',
#   'Martin Wiedmann (mw16)'),
#  (5479,
#   'FA14',
#   'FDSC',
#   'FDSC 6010',
#   'Lecture',
#   '3819',
#   'Morrison Hall 163',
#   'Mon',
#   '2:30pm - 4:25pm',
#   '',
#   'Syed Rizvi (ssr3)'),
#  (5597,
#   'FA14',
#   'FGSS',
#   'FGSS 2010',
#   'Lecture',
#   '6268',
#   'Uris Hall 262',
#   'Tues & Thurs',
#   '10:10am - 11:25am',
#   '',
#   'Jane Juffer (jaj93)'),
#  (5598,
#   'FA14',
#   'FGSS',
#   'FGSS 2140',
#   'Lecture',
#   '16801',
#   'Stimson Hall G01',
#   'Tues & Thurs',
#   '8:40am - 9:55am',
#   '',
#   'Joanne Fortune (jf11)'),
#  (5599,
#   'FA14',
#   'FGSS',
#   'FGSS 2350',
#   'Lecture',
#   '9330',
#   'Malott Hall 228-Bache Aud',
#   'Tues & Thurs',
#   '1:25pm - 2:40pm',
#   '',
#   'Elisha Cohn (ejc244)'),
#  (5600,
#   'FA14',
#   'FGSS',
#   'FGSS 2421',
#   'Lecture',
#   '6464',
#   'Uris Hall 262',
#   'Mon & Wed',
#   '12:20pm - 1:10pm',
#   '',
#   'Kathryn March (ksm8)'),
#  (5605,
#   'FA14',
#   'FGSS',
#   'FGSS 2780',
#   'Lecture',
#   '15916',
#   'Morrill Hall 106',
#   'Tues & Thurs',
#   '11:40am - 12:55pm',
#   '',
#   'Masha Raskolnikov (mr283)'),
#  (5606,
#   'FA14',
#   'FGSS',
#   'FGSS 3331',
#   'Lecture',
#   '9355',
#   'Uris Hall G88',
#   'Tues & Thurs',
#   '10:10am - 11:25am',
#   '',
#   'Arnika Fuhrmann (aif32)'),
#  (5607,
#   'FA14',
#   'FGSS',
#   'FGSS 3470',
#   'Lecture',
#   '17798',
#   'Rockefeller Hall 189',
#   'Mon & Wed',
#   '2:55pm - 4:10pm',
#   '',
#   'Chrissy Lau (cyl58)'),
#  (5608,
#   'FA14',
#   'FGSS',
#   'FGSS 3505',
#   'Lecture',
#   '16349',
#   'Goldwin Smith Hall G22',
#   'Tues & Thurs',
#   '1:25pm - 2:40pm',
#   '',
#   'Cheryl Finley (cf86)'),
#  (5610,
#   'FA14',
#   'FGSS',
#   'FGSS 3550',
#   'Lecture',
#   '15952',
#   'Rockefeller Hall 132',
#   'Mon & Wed',
#   '7:30pm - 8:45pm',
#   '',
#   'Ellis Hanson (eh36)'),
#  (5616,
#   'FA14',
#   'FGSS',
#   'FGSS 4460',
#   'Lecture',
#   '16224',
#   'Ives Hall 217',
#   'Mon & Wed',
#   '2:55pm - 4:10pm',
#   '',
#   'Francine Blau (fdb4)'),
#  (5627,
#   'FA14',
#   'FGSS',
#   'FGSS 6331',
#   'Lecture',
#   '15843',
#   'Uris Hall G88',
#   'Tues & Thurs',
#   '10:10am - 11:25am',
#   '',
#   'Arnika Fuhrmann (aif32)'),
#  (5632,
#   'FA14',
#   'FREN',
#   'FREN 1210',
#   'Lecture',
#   '6155',
#   'Morrill Hall 106',
#   'Mon',
#   '10:10am - 11:00am',
#   '',
#   'Colette Waldron (cdw1)'),
#  (5633,
#   'FA14',
#   'FREN',
#   'FREN 1210',
#   'Lecture',
#   '6156',
#   'Morrill Hall 106',
#   'Mon',
#   '11:15am - 12:05pm',
#   '',
#   'Colette Waldron (cdw1)'),
#  (5649,
#   'FA14',
#   'FREN',
#   'FREN 2060',
#   'Lecture',
#   '7939',
#   'Statler Hall 453',
#   'Mon, Wed & Fri',
#   '10:10am - 11:00am',
#   '',
#   'Joanna Luks (jgl7)'),
#  (5694,
#   'FA14',
#   'FSAD',
#   'FSAD 1250',
#   'Lecture',
#   '13667',
#   'M Van Rensselaer Hall 280',
#   'Mon, Wed & Fri',
#   '12:20pm - 1:10pm',
#   '',
#   'Denise Green (dng22)'),
#  (5695,
#   'FA14',
#   'FSAD',
#   'FSAD 1350',
#   'Lecture',
#   '14442',
#   'M Van Rensselaer Hall 151',
#   'Mon, Wed & Fri',
#   '9:05am - 9:55am',
#   '',
#   'Margaret Frey (mfw24)'),
#  ...]

# %% [markdown]
# # verify the schema connection

# %%
import os

current_dir = os.path.abspath("")

def init_db(
    db_path="roster_reviews.sqlite.db",
    schema_path=os.path.join(current_dir, "schema.sql"),
):
    conn = sqlite3.connect(db_path)
    with open(schema_path, "r") as f:
        conn.executescript(f.read())
    conn.commit()
    return conn

conn = init_db()
cur = conn.cursor()

tables = cur.execute("SELECT name FROM sqlite_master WHERE type='table';").fetchall()
print("Tables in the database:", tables)

# Check if the 'courses' table exists and display its schema
if ("courses",) in tables:
    schema = cur.execute("PRAGMA table_info(courses);").fetchall()
    print("\nSchema of the 'courses' table:", schema)

    # Query to check if there are FA14 courses
    cur.execute('SELECT * FROM courses WHERE semester="FA14"')
    rows = cur.fetchall()
    print("\nFA14 Courses:", rows)
else:
    print("\nThe 'courses' table does not exist in the database.")

conn.close()
# Out:
# Tables in the database: [('sqlite_sequence',), ('subjects',), ('courses',), ('course_descriptions',)]
#
# Schema of the 'courses' table: [(0, 'course_id', 'INTEGER', 0, None, 1), (1, 'semester', 'TEXT', 0, None, 0), (2, 'subject', 'TEXT', 0, None, 0), (3, 'name', 'TEXT', 0, None, 0), (4, 'type', 'TEXT', 0, None, 0), (5, 'section_number', 'TEXT', 0, None, 0), (6, 'location', 'TEXT', 0, None, 0), (7, 'days', 'TEXT', 0, None, 0), (8, 'time', 'TEXT', 0, None, 0), (9, 'dates', 'TEXT', 0, None, 0), (10, 'instructor', 'TEXT', 0, None, 0)]
#
# FA14 Courses: []
